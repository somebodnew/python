# %%
import random
import time
from enum import Enum, auto
from typing import List, Dict, Tuple, Optional, Set

# %%
class TimeOfDay(Enum):
    MORNING = auto()  # Утро
    DAY = auto()      # День
    EVENING = auto()  # Вечер
    NIGHT = auto()    # Ночь

class World:
    def __init__(self, width: int, height: int):
        self.width = width
        self.height = height
        self.grid = [[None for _ in range(width)] for _ in range(height)]
        self.time_of_day = TimeOfDay.MORNING
        self.time_ticks = 0
        self.entities = []
        self.day_counter = 0

    def add_entity(self, entity, x: int, y: int):
        if not (0 <= x < self.width and 0 <= y < self.height):
            return False

        if self.grid[y][x] is not None:
            return False

        entity.x = x
        entity.y = y
        entity.world = self
        self.grid[y][x] = entity
        self.entities.append(entity)
        return True

    def remove_entity(self, entity):
        if entity in self.entities:
            self.entities.remove(entity)

        if (0 <= entity.x < self.width and
            0 <= entity.y < self.height and
            self.grid[entity.y][entity.x] == entity):
            self.grid[entity.y][entity.x] = None

    def get_neighbors(self, x: int, y: int) -> List[Tuple[int, int]]:
        neighbors = []
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                if dx == 0 and dy == 0:
                    continue
                nx, ny = x + dx, y + dy
                
                if 0 <= nx < self.width and 0 <= ny < self.height:
                    neighbors.append((nx, ny))
        return neighbors

    def update_time(self):
        self.time_ticks += 1
        if self.time_ticks % 6 == 0:
            prev_time = self.time_of_day
            self.time_of_day = {
                TimeOfDay.MORNING: TimeOfDay.DAY,
                TimeOfDay.DAY: TimeOfDay.EVENING,
                TimeOfDay.EVENING: TimeOfDay.NIGHT,
                TimeOfDay.NIGHT: TimeOfDay.MORNING
            }[self.time_of_day]
            
            if prev_time == TimeOfDay.NIGHT and self.time_of_day == TimeOfDay.MORNING:
                self.day_counter += 1

    def step(self):
        self.update_time()

        for entity in self.entities[:]:
            if isinstance(entity, Plant):
                entity.grow()
        
        for entity in random.sample(self.entities[:], len(self.entities[:])):
            if isinstance(entity, Animal):
                entity.update_behavior()  # Обновление поведения
                entity.move()            # Движение
                entity.eat()             # Питание
                entity.reproduce()       # Размножение
                entity.update_hunger()   # Обновление уровня голода

                if entity.energy <= 0:
                    self.remove_entity(entity)

    def display(self):
        time_names = {
            TimeOfDay.MORNING: "Утро",
            TimeOfDay.DAY: "День",
            TimeOfDay.EVENING: "Вечер",
            TimeOfDay.NIGHT: "Ночь"
        }
        print(f"День: {self.day_counter} Время: {time_names[self.time_of_day]} (Шаг: {self.time_ticks})")
        print(f"Существ: {len(self.entities)} (Растений: {sum(1 for e in self.entities if isinstance(e, Plant))}, "
              f"Травоядных: {sum(1 for e in self.entities if isinstance(e, Pauvre))}, "
              f"Хищников: {sum(1 for e in self.entities if isinstance(e, Malheureux))})")

        for y in range(self.height):
            row = []
            for x in range(self.width):
                entity = self.grid[y][x]
                if entity is None:
                    row.append('.')
                elif isinstance(entity, Lumiere):
                    row.append('L' if entity.active else 'l')
                elif isinstance(entity, Obscurite):
                    row.append('O' if entity.active else 'o')
                elif isinstance(entity, Demi):
                    row.append('D' if entity.active else 'd')
                elif isinstance(entity, Pauvre):
                    row.append('P' if not entity.sleeping else 'p')
                elif isinstance(entity, Malheureux):
                    row.append('M' if not entity.sleeping else 'm')
            print(' '.join(row))
        print()

class Plant:
    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.growth_rate = 1  # Скорость роста
        self.active = False  # Активен ли рост
        self.health = 100    # Здоровье растения

    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        raise NotImplementedError

    def grow(self):
        if self.world is None:
            return

        self.active = self.can_grow_in_time(self.world.time_of_day)
        
        if not self.active:
            return

        self.health = min(100, self.health + 5)
        
        neighbors = self.world.get_neighbors(self.x, self.y)
        random.shuffle(neighbors)
        
        for nx, ny in neighbors:
            target = self.world.grid[ny][nx]
            
            if target is None and random.random() < 0.2:
                new_plant = self.__class__()
                if self.world.add_entity(new_plant, nx, ny):
                    continue
            elif (isinstance(target, Plant) and 
                  target != self and 
                  self.active and not target.active and 
                  random.random() < 0.3):
                target.health -= 20
                if target.health <= 0:
                    self.world.remove_entity(target)
                    new_plant = self.__class__()
                    self.world.add_entity(new_plant, nx, ny)

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

class Lumiere(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day == TimeOfDay.DAY

class Obscurite(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day == TimeOfDay.NIGHT

class Demi(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day in (TimeOfDay.MORNING, TimeOfDay.EVENING)

class Animal:
    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.energy = 100   # Уровень энергии
        self.hunger = 0     # Уровень голода
        self.sleeping = False  # Спящий режим
        self.age = 0        # Возраст (в шагах симуляции)

    def update_behavior(self):
        if self.world is None:
            return
        self.age += 1
        self.modify_behavior()  # Вызов специфичного поведения

    def modify_behavior(self):
        raise NotImplementedError

    def move(self):
        if self.sleeping or self.world is None:
            return

        possible_moves = [pos for pos in self.world.get_neighbors(self.x, self.y)
                         if self.world.grid[pos[1]][pos[0]] is None or 
                         (isinstance(self.world.grid[pos[1]][pos[0]], Plant) and 
                         random.random() < 0.3)]
        
        if possible_moves and random.random() < self.get_speed():
            nx, ny = random.choice(possible_moves)
            self.world.grid[self.y][self.x] = None
            self.x, self.y = nx, ny
            self.world.grid[ny][nx] = self
            self.energy -= 1  # Затраты энергии на движение

    def get_speed(self) -> float:
        return max(0.1, 1.0 - (self.hunger / 200))

    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        for nx, ny in self.world.get_neighbors(self.x, self.y):
            target = self.world.grid[ny][nx]
            if target is None:
                continue
                
            if any(isinstance(target, food_type) for food_type in self.get_food_types()):
                nutrition = self.get_nutrition(target)
                self.world.remove_entity(target)
                self.hunger = max(0, self.hunger - nutrition)
                self.energy += nutrition / 2
                return

    def get_food_types(self) -> Tuple:
        raise NotImplementedError

    def get_nutrition(self, food) -> int:
        if isinstance(food, Plant):
            return 30
        elif isinstance(food, Animal):
            return 50
        return 0

    def update_hunger(self):
        self.hunger += 2
        if self.hunger > 100:  # Голод снижает энергию
            self.energy -= 5

    def reproduce(self):
        if (self.energy < 80 or 
            self.hunger > 50 or 
            random.random() > 0.05 or 
            self.world is None):
            return

        for nx, ny in self.world.get_neighbors(self.x, self.y):
            target = self.world.grid[ny][nx]
            if (target is not None and 
                isinstance(target, self.__class__) and 
                target != self and 
                target.energy > 70 and 
                target.hunger < 50):
                
                for cx, cy in self.world.get_neighbors(self.x, self.y):
                    if self.world.grid[cy][cx] is None:
                        new_animal = self.__class__()
                        new_animal.energy = 60
                        if self.world.add_entity(new_animal, cx, cy):
                            self.energy -= 30
                            target.energy -= 30
                            return

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

class Pauvre(Animal):
    def __init__(self):
        super().__init__()
        self.aggression = 0    # Уровень агрессии
        self.group = set()     # Группа особей
        self.group_size = 1    # Размер группы

    def modify_behavior(self):
        self.sleeping = (self.world.time_of_day == TimeOfDay.NIGHT)
        
        self.aggression = min(100, self.hunger * 0.8 + len(self.group) * 5)
        
        self.update_group()

    def update_group(self):
        self.group = {self}
        for dx in range(-3, 4):
            for dy in range(-3, 4):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Pauvre)):
                    self.group.add(self.world.grid[ny][nx])
        
        self.group_size = len(self.group)
        
        if self.group_size > 5 and random.random() < 0.1:
            self.split_group()

    def split_group(self):
        avg_x = sum(m.x for m in self.group) / len(self.group)
        avg_y = sum(m.y for m in self.group) / len(self.group)
        
        subgroup1 = set()
        subgroup2 = set()
        
        for member in self.group:
            if member.x < avg_x or (member.x == avg_x and member.y < avg_y):
                subgroup1.add(member)
            else:
                subgroup2.add(member)
        
        for member in subgroup1:
            dx = -1 if random.random() < 0.5 else 0
            dy = -1 if dx == 0 else 0
            nx, ny = member.x + dx, member.y + dy
            if (0 <= nx < self.world.width and 
                0 <= ny < self.world.height and 
                self.world.grid[ny][nx] is None):
                self.world.grid[member.y][member.x] = None
                member.x, member.y = nx, ny
                self.world.grid[ny][nx] = member

    def get_food_types(self) -> Tuple:
        return (Lumiere,)

    def get_nutrition(self, food) -> int:
        if isinstance(food, Lumiere):
            if self.world.time_of_day == TimeOfDay.MORNING:
                return 50
            elif self.world.time_of_day == TimeOfDay.EVENING:
                return 20
            return 30
        return 0

    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        super().eat()
        
        if self.hunger > 50 and self.aggression > 60:
            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if (isinstance(target, Pauvre) and 
                    target not in self.group and 
                    random.random() < 0.3):
                    
                    damage = min(20, self.aggression / 3)
                    target.energy -= damage
                    self.energy -= 5
                    self.hunger = max(0, self.hunger - 10)
                    return

class Malheureux(Animal):
    def __init__(self):
        super().__init__()
        self.pack = set()    # Стая
        self.hunting = False # Режим охоты

    def modify_behavior(self):
        self.sleeping = (self.world.time_of_day in (TimeOfDay.DAY, TimeOfDay.NIGHT))
        
        self.hunting = (not self.sleeping and self.hunger > 40)
        
        self.update_pack()

    def update_pack(self):
        self.pack = {self}
        for dx in range(-2, 3):
            for dy in range(-2, 3):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Malheureux)):
                    self.pack.add(self.world.grid[ny][nx])
        
        if len(self.pack) > 3:
            for member in self.pack:
                member.aggression = True

    def get_food_types(self) -> Tuple:
        return (Demi, Obscurite, Pauvre)

    def get_speed(self) -> float:
        base_speed = super().get_speed()
        if self.hunting:
            return base_speed * 1.2  # Быстрее при охоте
        return base_speed * 0.8      # Медленнее в обычном режиме

    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        super().eat()
        
        if self.hunting and self.hunger > 40:
            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if isinstance(target, Pauvre) and random.random() < 0.4:
                    # Бонус за размер стаи
                    pack_bonus = 1.0 + (len(self.pack) * 0.2)
                    damage = min(30, 15 * pack_bonus)
                    target.energy -= damage
                    self.energy -= 5
                    self.hunger = max(0, self.hunger - 25)
                    
                    if target.energy <= 0:
                        self.world.remove_entity(target)
                    return

def initialize_world(world: World, plant_density: float = 0.2, 
                    pauvre_count: int = 10, malheureux_count: int = 5):
    plant_classes = [Lumiere, Obscurite, Demi]  # Доступные типы растений
    
    num_plants = int(world.width * world.height * plant_density)
    
    for _ in range(num_plants):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                plant_class = random.choice(plant_classes)
                plant = plant_class()
                if world.add_entity(plant, x, y):
                    break
    
    for _ in range(pauvre_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                pauvre = Pauvre()
                if world.add_entity(pauvre, x, y):
                    break
    
    for _ in range(malheureux_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                malheureux = Malheureux()
                if world.add_entity(malheureux, x, y):
                    break

def run_simulation(width: int = 20, height: int = 20, 
                   plant_density: float = 0.2, 
                   pauvre_count: int = 10, malheureux_count: int = 5,
                   steps: int = 100, delay: float = 0.5):
    world = World(width, height)
    initialize_world(world, plant_density, pauvre_count, malheureux_count)
    
    try:
        for _ in range(steps):
            world.step()      # Шаг симуляции
            world.display()   # Отображение состояния
            time.sleep(delay) # Задержка для удобства наблюдения
    except KeyboardInterrupt:
        print("\nСимуляция остановлена пользователем.")
    except Exception as e:
        print(f"Ошибка: {e}")
    
    print("Симуляция завершена.")
    print(f"Итоговые показатели: День {world.day_counter}, Всего существ: {len(world.entities)}")
    print(f"Растений: {sum(1 for e in world.entities if isinstance(e, Plant))}")
    print(f"Травоядных: {sum(1 for e in world.entities if isinstance(e, Pauvre))}")
    print(f"Хищников: {sum(1 for e in world.entities if isinstance(e, Malheureux))}")

if __name__ == "__main__":
    run_simulation(
        width=20,            # Ширина мира
        height=20,           # Высота мира
        plant_density=0.2,   # Плотность растений (0.0 - 1.0)
        pauvre_count=15,     # Начальное количество травоядных
        malheureux_count=5,  # Начальное количество хищников
        steps=200,           # Количество шагов симуляции
        delay=0.3            # Задержка между шагами (сек)
    )
# Out:
# День: 0 Время: Утро (Шаг: 1)
# Существ: 118 (Растений: 98, Травоядных: 15, Хищников: 5)
# . o . . l o . D d D . P . . P . . . . .
# . P d D . . . . . . . . d . . . . . . .
# . . D . . . . l . o . D d . . . . . o .
# . o l d . . P . . l d D D . . D . . . .
# . l . . . . . . l . P . d . . . . o . .
# . . . . . d D P . . . o o . . . P . . .
# . . . d M d D . P . M . . . . . d . D l
# . . D . . d o . l o . . o . . . o D o .
# . o l . . . . . . . . . . . . . . . . .
# . l . . . . o . l . . . . . . . . . . M
# . . o . . . . o . . . . . . . . l . l .
# . P . o . . . . . . . . o . . . o . . .
# d . . . . . . . l . . l . o . . . . . .
# . D . . . P . . . P o . o . . . . . . .
# d . o o . . M . . l . . . . l . . o . .
# P . . . . . l . . D o M . . . . . . . o
# . . . . . o . o . . . . . P . . o . . .
# . . . . . . . . . . . . . . . . . . . o
# . . . P . . . d P . . . o . . . o . . D
# . o . . . . l d D l o . . o . . . . d D
#
# День: 0 Время: Утро (Шаг: 2)
# Существ: 147 (Растений: 127, Травоядных: 15, Хищников: 5)
# . o . d l o . D D D d . . P . . . . . .
# . . D D d . . d d . . d P . . . . . . .
# . P D . d . . l . o d D D . . . . . o .
# . o l D . . . . . l D D D . . D d . . .
# . l . . . d . P P P . . D . . d d o . .
# . . . . . D D . . . . o o . . d . . . d
# . d . D M D D . . d M . . . . . D P D l
# . . D d d D o . P o . . o . . . o D o .
# . o l . d . d . . . . . . . . . d . . .
# . l . . . . o . l . . . . . . . . . . .
# . . o . . . . o . . . . . . . . l . l M
# . . . o . . . . . . . . o . . . o . . .
# D P . . . P . . l . P l . o . . . . . .
# . D . . . . . . . . o . o . . . . . . .
# D d o o . . . M d l . . . . l . . o . .
# . . . . . . l . . D o . M . . . . . . o
# P . . . . o . o d . . . P . . . o . . .
# . . . . . . d . d P . . . . . . . . . o
# . . . . . . . D . d . . o . . . o . . D
# . o . P . . l D D l o . . o . . . . D D
#
# День: 0 Время: Утро (Шаг: 3)
# Существ: 182 (Растений: 162, Травоядных: 15, Хищников: 5)
# . o d D l o . D D D D P d . . . . . . .
# . d D D D . . D D d d D . d P . . . . .
# . . D . D d . l . o D D D d . d d d o .
# d P l D . . . P . l D D D . . D D d . .
# . l . . . D d . . P . d D . d D D o d .
# . . . . M D D d . P d o o . . D d . P D
# . D d D . D D . . D . . . . . d D . D l
# . d D D D D o . . o . M o . . . o D o .
# . o l . D d D P . . . . . . . . D . . .
# . l . . . . o . l . . . . . . d . . . .
# . . o . . . . o . . . . . . . . l . l .
# . P . o . . P . . . . . o . . . o . M .
# D . d . . . . . l P . l . o . . . . . .
# . D . . . . . d . . o . o . . . . . . .
# D D o o . . . . D l . . . M l . . o . .
# . . d . . . l . M D o P . . . . . . . o
# P . . . . o . o D d . . . . . . o . . .
# . . . . . . D d D . P . . . . . . . . o
# . . . . P . d D d D . . o . . . o d . D
# . o . . . . l D D l o . . o . . . . D D
#
# День: 0 Время: Утро (Шаг: 4)
# Существ: 216 (Растений: 196, Травоядных: 15, Хищников: 5)
# . o D D l o d D D D P . D d . P . . . .
# d D D D D . . D D D d D . D . . . . . .
# P d D d D D . l . o D D D D d D D D o .
# D . l D . . . . . l D D D d d D D D . d
# . l . . d D P d P . d D D . D D D o D .
# d . d M . D D D . . D o o d d D D d . D
# . D D D d D D . d D P . . . . D D d D P
# . D D D D D o . d o d . o . . . o D o .
# . o l d D D D . . . M . . . . d D . . .
# . l . d . . o P l . . . . . . D . . . .
# d . o . . . . o . . . . . . . . l . l .
# P . . o . . . . . P . . o . . . o . M .
# D d D . . P . . l . . l . o . . . . . .
# d D . . . . . D d d o . o . . . . . . .
# D D o o . . . . D l . . P M l . . o . .
# . d D . . . l M . D o . . . . . . . . o
# . . . . . o . o D D . . . . . . o . . .
# P . . . . d D D D d . . . . . . . . d o
# . . . . . P D D D D . P o . . . o D . D
# . o . . . . l D D d o . . o . . . . D D
#
# День: 0 Время: Утро (Шаг: 5)
# Существ: 258 (Растений: 238, Травоядных: 15, Хищников: 5)
# . o D D l o D D D D . P D D . . . . . .
# D D D D D . . D D D D D . D d P d d . .
# . D D D D D . l d o D D D D D D D D o .
# P d l D d d d P . l D D D D D D D D . D
# . l . d D D . d . P D D D d D D D d D d
# D d D M d D D D d . D o o D D D D d d D
# d D D D D D D d D D P d . d d D D d P .
# . D D D D D o d D d D d o . . . o D o .
# . o d D D D D . d M . . . . . D D d . .
# . l . D . . o . l . . . . . d D . d . .
# D P o . . . P o . . P . . . . . l . l .
# . . d o . . . . . . . . o . . . o M . .
# D D D d P . . . l . d l . o . . . . . .
# D D . . . . . D D D o . o P . . . . . .
# D D o o . . . . D d . . . . l . . o . .
# d D D . . . l . d D o . . M . . . . . o
# d d . . . o M o D D d . . . . . o . . d
# . . . . P D D D D D . . . . . . d . D o
# . P . . . . D D D D P . o . . . o D . D
# . o . . . d d D D D o . . o . . . d D D
#
# День: 0 Время: День (Шаг: 6)
# Существ: 273 (Растений: 253, Травоядных: 15, Хищников: 5)
# . o d d L o d d d d P . d d . . . . . .
# d d d d d . . d d d d d . d d . P d . .
# . d d d d d l L d o d d d d d d d d o .
# P d L d d d d . l L P d d d d d d d . d
# . L . d d d P d . . d d d d d d d d d d
# d d d m d d d d d l d P o d d d d d d d
# d d d d d d d d d d . d . d d d d P . .
# . d d d d d o d d d d d o . . . o d o .
# . o d d d d d l d m . . . . . d d d . .
# l L l d . . o . L . . . . . d d l d . l
# d . o . . . . o . . . . . . . l L l L .
# P . d o . . P l . P l . o . . l o m . .
# d d d d . . . . L . d L l o . . . . . .
# d d . . P . . d d d o . o . . . . . . .
# d d o o . . . . d d . . . P L l . o . .
# d d d . . . L . d d o . . m . . . . . o
# d d . . . o m o d d d . . . . . o . . d
# P . . . . d d d d P . . . . . . d . d o
# . . . . P . d d d d . . o . . . o d . d
# . o . . . d d d d d o . . o . . . d d d
#
# День: 0 Время: День (Шаг: 7)
# Существ: 286 (Растений: 266, Травоядных: 15, Хищников: 5)
# . o d d L o d d d d . . d d . . . . . .
# d d d d d . . d d P d d . d d P . d . .
# P d d d d d L L d o d d d d d d d d o .
# . d L d d d d . L L . d d d d d d d . d
# . L . d d d . P l l P d d d d d d d d d
# d d d m d d d d d L d . o d d d d d d d
# d d d d d d d d d d P d . d d d d . P .
# . d d d d d o d d d d d o . . . o d o .
# l o d d d d d L d m . . . . . d d d l .
# L L L d . . o . L l . . . . d d L d . L
# d P o . . . . o . P . . . . l L L L L l
# . . d o . P . L l . L . o . . L o m . .
# d d d d . . l . L l d L L o . . . . . .
# d d . . . . . d d d o . o . . . . . . .
# d d o o . P . . d d . . . . P L . o . .
# d d d . . l L . d d o . . m l l . . . o
# d d . . . o m o d d d . . . . . o . . d
# . P . . . d d d d . P . . . . . d . d o
# . . . . . . d d d d . . o . . . o d . d
# . o . . . P d d d d o . . o . . . d d d
#
# День: 0 Время: День (Шаг: 8)
# Существ: 304 (Растений: 284, Травоядных: 15, Хищников: 5)
# . o d d L o d d d d . . d d . P . . . .
# d d d d d . . d d P d d . d d . . d . .
# P d d d d d L L d l d d d d d d d d o .
# . d L d d d P l L L P d d d d d d d . d
# . L . d d d . . L L . d d d d d d d d d
# d d d m d d d d d L d P o d d d d d d d
# d d d d d d d d d d . d . d d d d P . .
# . d d d d d o d d d d d o . . . o d o l
# L o d d d d d L d m . . . . . d d d L .
# L L L d . . o l L L l . . . d l L l l L
# P . o . . . . o l . P l . . L L L L L L
# . . d o . . l L L l L . o . . L o m . l
# d d d d . P L l L L d L L o . . . . . .
# d d . . . l . d d d o . o l P . l . . .
# d d o o . . l . d d . . . . . L l o . .
# d d d . P L L . d d o . . m L L . . . o
# P d . . l o m o d d d . . . l . o . . d
# . . . . . d d d d . P . . . . . d . d o
# . . . . P . d d d d . . o . . . o d . d
# . o . . . . d d d d o . . o . . . d d d
#
# День: 0 Время: День (Шаг: 9)
# Существ: 324 (Растений: 304, Травоядных: 15, Хищников: 5)
# . o d d L o d d d d P . d d . . P . . .
# d d d d d l . d d . d d . d d . . d . .
# P d d d d d L L d L d d d d d d d d o .
# . d L d d d . L L L P d d d d d d d . d
# l L . d d d . P L L l d d d d d d d d d
# d d d m d d d d d L d . o d d d d d d d
# d d d d d d d d d d . d P d d d d . P .
# . d d d d d o d d d d d o . . . o d o L
# L o d d d d d L d m . . . . . d d d L .
# L L L d . . o L L L L l . . d L L L L L
# . P o l . . l o L l P L . . L L L L L L
# . . d o P . L L L L L l o . l L l m . L
# d d d d l . L L L L d L L o . P l . . l
# d d . . . L . d d d o l o L . l L . . .
# d d o o . P L . d d . . l . l L L o . .
# d d d . . L L l d d o . . m L L l l . o
# . d . l L l m o d d d . . . L . o . . d
# P . . . . d d d d . . . . . . . d . d o
# . . . . . . d d d P . . o . . . o d . d
# . o . . P . d d d d o . . o . . . d d d
#
# День: 0 Время: День (Шаг: 10)
# Существ: 347 (Растений: 327, Травоядных: 15, Хищников: 5)
# . o d d L o d d d d . P d d . . P . . .
# d d d d d L . d d . d d . d d . . d . .
# . P d d d d L L d L P d d d d d d d o .
# l d L d d d l L L L . d d d d d d d . d
# L L . d d d . . L L L d d d d d d d d d
# d d d m d d d d P L d l o d d d d d d d
# d d d d d d d d l d . d . d d d d P . .
# . d d d d d l d d d d d o P . . o d l L
# L o d d d d d L l m l . . . . d d d L .
# L L L d . l l L L L L L . . l L L L L L
# . . o L . . L l L P . L l l L L L L L L
# . P d o . l L L L L L L l l L L L m l L
# d d d d L P L L L L l L L o l . L . l L
# d d . . l P . d d d o L l L l L P l . l
# d d o o . . L . d d . l L . L L L o . .
# d d d . . L L L d d o . . m L L L L . o
# . d . L L L m o d d d . . . L l o l l d
# . P . . l d d d d . P . . . l . d . d o
# . . . . . . d d d . . . o . . . o d . d
# . o . . . P d d d d o . . o . . . d d d
#
# День: 0 Время: День (Шаг: 11)
# Существ: 358 (Растений: 338, Травоядных: 15, Хищников: 5)
# . o d d L l d d d d P . d d . . . P . .
# d d P d d L l d d P d d . d d . . d . .
# l . d d d d L L . L . d d d d d d d o .
# L l L d d d L L L L l d d d d d d d . d
# L L l d d d . l L L L d d d d d d d d d
# d d d m d d d d . L d . o d d d d d d d
# d d d d d d d P L d . d P d d d d P . l
# . d d d d d . d d d d d o . . . o d L L
# L l d d d d l L L m L . . . . d d d L .
# L L L d . L L L L . L L l l L L L L L L
# . . o L . . L L L . P L L L L L L L L L
# P . d o . L L L L L L L L L L L . m L L
# d d d d P . L L L L L L L l L l L P L L
# d d . . L . P d d d o L L L L L . L l L
# d d o o l . L . d d . L L l L L L o l .
# d d d . l L L L d d o . . m L L L L l o
# . d . L L L m o d d d . . . L L o L L d
# . . . . . d d d d . . . . . L . d . d o
# . . P . . P d d d P . . o l l . o d . d
# . o . . . . d d d d o . . o . . . d d d
#
# День: 0 Время: Вечер (Шаг: 12)
# Существ: 374 (Растений: 356, Травоядных: 13, Хищников: 5)
# . o D D l l D D D D . P D D . . P . . .
# D D . D D l l D P . D D d D D . d D d .
# . P D D D D l l . l d D D D D D D D d .
# l l l D D D l l l l l D D D D D D D d D
# l l l D D D . l l l l D D d D D D D D D
# D D . M d D D D d l D d o D D D D d d D
# D D d D D D P . l D . D . D D D P . d l
# . D D D D D . d D d D D o P d d d D l l
# l l D D D D l l l . l d . . . D D D l .
# . l l D . l l l l M l l l l l l l l l l
# . P o l d . l l l . . l l l l l l l l l
# . d D o P l l l l l l l l l l l M . l l
# D D D D . . l l l l l l l l l l l . l l
# D D d . l P . D d D o l l l l l P l l l
# D D o o l . l . D D . l M l l l l o l .
# D D D . l l l l D D o . . . l l l l l o
# . D d l l l . d D D D . . . l l o l l D
# . . . . P D . M D d . . . . l . D . D o
# . . . P . . D D P . . . o l l d o D d D
# . o . . . d D D D D o . . o . . d D D D
#
# День: 0 Время: Вечер (Шаг: 13)
# Существ: 405 (Растений: 387, Травоядных: 13, Хищников: 5)
# d d D D l l D D D D . . D D d d . . d d
# D P d D D l l D . P D P d D D P D D D .
# d . D D D D l l . l D D D D D D D D D d
# l l d D D D l l l l d D D D D D D D D D
# l l l M D D d l l l l D D D D D D D D D
# D D d . D D D D D l D D d D D D D D d D
# D D D D D D . d d D . D . D D D . d D l
# d D D D D D d P D D D D o . D D d P l l
# l l D D D D l l l M l D d P d D D D l .
# . l l D d l l l l . l l l l l l l l l l
# d . d l D . l l l . . l l l l l l l l l
# . P D d . l l l l l l l l l l l . M l l
# D D D D P . l l l l l l l l l l l . l l
# D D D . l . d D D D d l l l l l P l l l
# D D o o P . l d D D d l . l l l l o l .
# D D D . l l l l D D o . . M l l l l l o
# d D D l P l . D D D D . . . l l o l l D
# d . . . . D d . M D d . . . l d D d D o
# . . . . d d D D P d . . o l l D o D D D
# . o . . P D D D D D o . . o d . D D D D
#
# День: 0 Время: Вечер (Шаг: 14)
# Существ: 426 (Растений: 408, Травоядных: 13, Хищников: 5)
# D D D D l l D D D D P . D D D D P d D D
# D . d D D l d D . . D . d D D . D D D d
# D P D D D D l l . l P D D D D D D D D D
# l d D D D D l l l d D D D D D D D D D D
# l l l M D D D l l d l D D D D D D D D D
# D D D d D D D D D l D D d D D D D D D D
# D D D D D D d D d D . D . D D D d P D l
# D D D D D D P . D D D D P d D D D . l l
# l d D D D D l l d . l D D . D D D D l .
# . l d D D d l l l . M l l l l l l l l l
# D d D l D d l l l . . l l l l l l l l l
# d . D D . l l l l l l l l l l l . M l l
# D D P D P . l l l l l l l l l l l . l l
# D D D d l . D D D D D l l l l l P l l l
# D D d o . . l D D D D l M l l l l o l .
# D D D P l l l d D D o d . . l l l l l o
# D D D l . l d D D D D . . . l l o l l D
# D . . d P D D M . D D . . . l D D D D o
# . d . d D D D D . P d . o l l D d D D D
# . o . P . D D D D D o . . o D . D D D D
#
# День: 0 Время: Вечер (Шаг: 15)
# Существ: 449 (Растений: 431, Травоядных: 13, Хищников: 5)
# D D D D l l D D D D P d D D D P . D D D
# D P D D D l D D d d D d D D D d D D D D
# D . D D D D l d . d . D D D D D D D D D
# l D D D D D d l l D D P D D D D D D D D
# l d d . D D D d l d l D D D D D D D D D
# D D M D D D D D D d D D D D D D D P D D
# D D D D D D D D D D d D d D D D D . D l
# D D D D D D . P D D D D . P D D D d l d
# l D D D D D d l D d d D D . D D D D l .
# d d D D D D l l l d M l l l l l l l l l
# D D D d D D l l l . . l l l l l l l l l
# D d D D d l l l l l l l l l l l . M l l
# D D . D . . l l l l l l l l l l l . l l
# D D P D P . D D D D D l l l l l P l l l
# D D D o . . l D D D D l M l l l l o l .
# D D D . l l l D D D o D d . l l l l l o
# D D P l P l D D D D D . . . l l d l l D
# D d d D . D D M d D P . . . l D D D D o
# . D . D D D D D d . D d o l l D D D D D
# . o . . P D D D D D d d . o D d D D D D
#
# День: 0 Время: Вечер (Шаг: 16)
# Существ: 469 (Растений: 450, Травоядных: 14, Хищников: 5)
# D D D D d l D D D D P d D D D . d D D D
# D . D D D l D D D D D d D D D d P D D D
# D P D D D D l D . D P D D D D D D D D D
# l D D D D D D d l D D . D D D D D D D D
# d D D M D D D D d D d D D D D D D D D D
# D D . D D D D D D d D D D D D D D . D D
# D D D D D D D D D D D D D P D D D P D d
# D D D D D D d . D D D D d . D D D d d D
# l D D D D D D l P D D D D d D D D D l d
# d D D D D D l l l D . M l l l l l l l l
# D D D D D D l l l d . l l l l l l l l l
# D d D D D l l l l l l l l l l l . M l l
# D D d P d . l d l d l l l l l l l . l l
# D D . P P d D D D D D l l l l l P l l l
# D D D o . . l D D D D l . l l l l o l .
# D D P d l l d D D D o M D . l l l l l o
# D D . l . l D D D D P d . . l l D l d D
# D D D D P D D . d D . d . . l D D D D d
# d D d D D D D M d d D D o l l D D D D D
# . o d d P D D D D D D D . o D D D D D D
#
# День: 0 Время: Вечер (Шаг: 17)
# Существ: 489 (Растений: 470, Травоядных: 14, Хищников: 5)
# D D D D D d D D D D . P D D D d D D D D
# D d D D D d D D D D D d D D D d P D D D
# P . D D D D d D d P . D D D D D D D D D
# l D D D M D D D d D D d D D D D D D D D
# D D D . D D D D D D D D D D D D D D D D
# D D . D D D D D D D D D D D P D D d D D
# D D D D D D D D D D D D D . D D D . D D
# D D D D D D D . D D D D D d D D D d P D
# d D D D D D D P . D D D D D D D D D l D
# D D D D D D l l l D d M l l l l d l l l
# D D D D D D l l l D . l l l l l l l l l
# D d D P D d l l l l l l l l l l . . l l
# D D D P D d d D l D l l l l l l M . l l
# D D d . P D D D D D D l l l l l P l l l
# D D D d d d d D D D D d d l l l l o l .
# D D . D l l D D D P d . D d l l l l l o
# D D P P d d D D D D . M . . l l D d D D
# D D D D . D M d d D d D d . l D D D D D
# D D D D D D D . D d D D o l l D D D D D
# d o D D P D D D D D D D d o D D D D D D
#
# День: 0 Время: Ночь (Шаг: 18)
# Существ: 490 (Растений: 471, Травоядных: 14, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p . d d d d d d d p . d d d d d d d d d
# l d d d m d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d . d d d . d d
# d d d d d d d . d d d d d d d d d d p d
# d d d d d d d p . d d d d d d d d d l d
# d d d d d d l l l d d m l l l l d l l l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l l O l o
# d d . d l l d d d p d . d d l l l l l O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d . l d d d d d
# d d d d d d d . d d d d O l o d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 0 Время: Ночь (Шаг: 19)
# Существ: 490 (Растений: 471, Травоядных: 14, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p . d d d d d d d p . d d d d d d d d d
# l d d d m d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d . d d d . d d
# d d d d d d d . d d d d d d d d d d p d
# d d d d d d d p . d d d d d d d d d l d
# d d d d d d l l l d d m l l l l d l l l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l l O l O
# d d . d l l d d d p d . d d l l l l o O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d . l d d d d d
# d d d d d d d . d d d d O l O d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 0 Время: Ночь (Шаг: 20)
# Существ: 490 (Растений: 471, Травоядных: 14, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p . d d d d d d d p . d d d d d d d d d
# o d d d m d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d . d d d . d d
# d d d d d d d . d d d d d o d d d d p d
# d d d d d d d p . d d d d d d d d d l d
# d d d d d d l l l d d m l l l l d l l l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l l O l O
# d d . d l l d d d p d . d d l l l o O O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d . l d d d d d
# d d d d d d d . d d d d O l O d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 0 Время: Ночь (Шаг: 21)
# Существ: 491 (Растений: 472, Травоядных: 14, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p o d d d d d d d p . d d d d d d d d d
# O d o d m d d d d d d d d d d d d d d d
# d d d . d d d d d d o d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d . d d d . d d
# d d d d d d d . d d d d d O d d d d p d
# d d d d d d d p . d d d d d d d d d l d
# d d d d d d l l l d d m l l l l d l l l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l l O l O
# d d . d l l d d d p d . d d l l l O O O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d . l d d d d d
# d d o d d d d . d d d d O l O d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 0 Время: Ночь (Шаг: 22)
# Существ: 494 (Растений: 474, Травоядных: 15, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p O d d d d d d d p . d d d d d d d d d
# O o O d m d d d d d d d d d d d d d d d
# d d d . d d d d d d O d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d o d d d . d d
# d d d d d d d . d d d d d O d d d d p d
# d d d d d d d p . d d d d o d d d d l d
# d d d d d d l l l d d m l l l l d l l l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l l O o O
# d d P d l l d d d p d . d d l l l O O O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d o l d d d d d
# d d O d d d d . d d d d O l O d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 0 Время: Ночь (Шаг: 23)
# Существ: 494 (Растений: 474, Травоядных: 15, Хищников: 5)
# d d d d d d d d d d . p d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# p O d d d d d d d p . d d d d d d d d d
# O O O d m d d d d d o d d d d d d d d d
# o d d . d d d d d d O d d d d d d d d d
# d d . d d d d d d d d d d d p d d d d d
# d d d d d d d d d d d d d O d d d . d d
# d d d d d d d . d d d d d O d d d d p d
# d d d d d d d p . d d d d O d d d d o d
# d d d d d d l l l d d m l l l l d l o l
# d d d d d d l l l d . l l l l l l l l l
# d d d p d d l l l l l l l l l l . . l l
# d d d p d d d d l d l l l l l l m . l l
# d d d . p d d d d d d l l l l l P l l l
# d d d d d d d d d d d d d l l l o O O O
# d d p d l l d d d p d . d d l l o O O O
# d d p p d d d d d d . m . . l l d d d d
# d d d d . d m d d d d d d O l d d d d d
# d d O d d d d . d d d d O o O d d d d d
# d O d d p d d d d d d d d O d d d d d d
#
# День: 1 Время: Утро (Шаг: 24)
# Существ: 502 (Растений: 482, Травоядных: 15, Хищников: 5)
# D D D D D D D D D D d P D D D D D D D D
# D d D D D D D D P D D d D D D d P D D D
# . o D . D D d D D . d D D D d D D D D D
# o P o D M D d d D D o d D D D D D D D D
# o d d d D D d d D D o D D D D D D D D D
# D D d D D D D D D d d d D D P D D D d D
# D D D D D D D d D D d D d o D D d d D d
# D D D D D D d d D D D D d o d D d D . P
# D D D D D D P . . D . D D o D D D D o D
# D D D D D D . l l D d M l l l d D l o l
# D d D d D D l l l D d l l l l l l l l l
# D D D P D D l l l l l l l l l l . . l l
# D D d . D D D D d D l l l l l l M . l l
# d D P d . D D D D D D l l l l l . l l l
# D D D D P D D D D D D D D l l l o o o o
# D D . D . l d D P . D d D D l l o o o o
# D D P P D . D D D D . . d d l d D D D D
# D P D D d D M d d D D M D o d D D D D D
# d D o D P D D d d d D D o o o D d D D D
# D o D D . D D D D D D d D o D D D D D D
#
# День: 1 Время: Утро (Шаг: 25)
# Существ: 517 (Растений: 497, Травоядных: 15, Хищников: 5)
# D D D D D D D D P D d . D D D D D D D D
# D D D D D D D D . D P D D D D P . D D D
# d P D d D D D D D d d D D D D D D D D D
# o . o D M D d d D D d D D D D D D D D D
# o D d D D D D D D D o D D D D D D D D D
# D D d D D D D D D d D D D D . D D D d D
# D D D D D D D d D D D D D o P D d D D D
# D D D D D D d P D D D D D o D D d D . P
# D D D D D D . d d D d D D o D D D D d D
# D D D D D D . l l D D . l l l D D l o l
# D d D D D D l l l D D l M l l l l l l l
# D D D . P D d l l d l l l l l l . . l l
# D D P d D D D D D D d l l l l l M . l l
# D D . d d P D D D D D l l l l l . l l l
# D D D D . D D D D P D D D l l l o o o o
# D D d D P d D D . d D D D D l l o o o o
# D P . . D d D D D D d M D D d D D D D D
# P . D D D D M D D D D . D o D D D D D D
# D D o D P D D d d d D D o o o D D D D D
# D o D D d D D D D D D D D o D D D D D D
#
# День: 1 Время: Утро (Шаг: 26)
# Существ: 527 (Растений: 507, Травоядных: 15, Хищников: 5)
# D D D D D D D D . D D d D D D P D D D D
# D D D D D D D P . D P D D D D . d D D D
# D P D D D D D D D D d D D D D D D D D D
# o d d M . D D D D D D D D D D D D D D D
# d D D D D D D D D D d D D D D D D D D D
# D D D D D D D D D D D D D D d D D D d D
# D D D D D D D d D D D D D P . D D D D D
# D D D D D D D . D D D D D d D D D D P .
# D D D D D D d D P D D D D o D D D D D D
# D D D D D D . d d D D . l l d D D d o l
# D D D D D D l l l D D l M l l l l l l l
# D D D d . D D d d D l l l l l l . . l l
# D P . d P D P D D D D l l l l l M . l l
# D D . D d . D D D P D d l l l l . l l l
# D D D D . D D D D . D D D l l l o o o o
# D P d D . D D D d D D D D D l l d o o o
# D . d P D d D D D D d . D D D D D D D D
# P d D D D D M D D D D d M o D D D D D D
# D D d D P D D D d D D D o d o D D D D D
# D d D D D D D D D D D D D o D D D D D D
#
# День: 1 Время: Утро (Шаг: 27)
# Существ: 543 (Растений: 523, Травоядных: 15, Хищников: 5)
# D D D D D D D D d D D P D D P . D D D D
# D D D D D D D . P D . D D D D d d D D D
# D P D D M D D D D D d D D D D D D D D D
# o d d . d D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D d D D D d D
# D D D D D D D d D D D D P . d D D D D D
# D D D D D D D d D D D D D D D D D D . d
# D D D D D D D P . D D D D o D D D P D D
# D D D D D D d D D D D d l l D D D D o l
# D D D D D D l l d D D M . l l l l l l l
# D D D d d D D D D D l d l l l M . . l l
# D . d D . D . D D D D l l l l l . . l l
# D D P D D P D P D . D d l l l l . l l l
# D D D D . D D D D P D D D l l l o o o o
# D P d D d D D D D D D D D D d l D o o o
# D d D P D d D D D D d d D D D D D D D D
# . d D D D P . D D D D d M o D D D D D D
# P D D D . M D D d D D D o D o D D D D D
# D D D D D D D D D D D D D o D D D D D D
#
# День: 1 Время: Утро (Шаг: 28)
# Существ: 557 (Растений: 537, Травоядных: 15, Хищников: 5)
# D D D D D D D D P D D . D D P d D D D D
# D D P D D D D . . D d P D D D d D D D D
# D . D D . M D D D D d D D D D D D D D D
# d d d d D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D . d d D D D D D
# D D D D D D D d D D D D D P D D D D d D
# D D D D D D P . d D D D D d D D D P D D
# D D D D D D d D D D D d l l D D D D d l
# D D D D D D l l D D D . d l l l l l l l
# D D D D D D D D D D M D l l l . . . l l
# D d D D P D d D P D D l l l l l M . l l
# D D . D D . D . P d D D l l l l . l l l
# D D D P d D D D D . D D D d l l o o o o
# D . d D d D D D D D D D D D D l D d o o
# D P D P D D D D D D D d D D D D D D D D
# d D D D D . d D D D D D . M D D D D D D
# P D D D M P D D d D D D d D d D D D D D
# D D D D D D D D D D D D D o D D D D D D
#
# День: 1 Время: Утро (Шаг: 29)
# Существ: 571 (Растений: 551, Травоядных: 15, Хищников: 5)
# D D D D D D D P . D D d D D . D D D D D
# D P . D D D D d d D d . P D D P D D D D
# D d D D d . D D D D d D D D D D D D D D
# D d d D D M D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D d d d D D D D D
# D D D D D D D d D D D D P . D D P D d D
# D D D D D D . P D D D D D D D D D . D D
# D D D D D D D D D D D D d l D D D D D d
# D D D D D D d d D M D d D l l l l l l l
# D D D P D D D D D D . D l l l . M . l l
# D d D D . D d D . D D l l l l l . . l l
# D D d D D d D P . P D D d d l l . l l l
# D D D . d D D D D d D D D D l l o o o o
# D P D D P D D D D D D D D D D d D D o o
# D . P . D D D D D D D d D D D D D D D D
# D D D D D M d D D D D D d . D D D D D D
# . P D D . . D D d D D D M D D D D D D D
# D D D D P D D D D D D D D o D D D D D D
#
# День: 1 Время: День (Шаг: 30)
# Существ: 575 (Растений: 555, Травоядных: 15, Хищников: 5)
# d d d d d d d . P d d d d d P d d d d d
# d . P d d d d d d d d . P d d . d d d d
# d d d d d . d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d . P d d . d d d
# d d d d d d P . d d d d d d d d d P d d
# d d d d d d d d d d d d d L d d d d d d
# d d d d d d d d d m d d d L L L L L L L
# d d d . d d d d d d . d L L L . m l L L
# d d d d P d P d . d d L L l L L . l L L
# d d d d d d d . P . d d d d L l l L l L
# d d d . d d d d d d d d d d L L o o o o
# d P d d . d d d d d d d d d d d d d o o
# d . P . P d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d . d d d d d d
# P . d d P . d d d d d d m d d d d d d d
# d d d d . d d d d d d d d o d d d d d d
#
# День: 1 Время: День (Шаг: 31)
# Существ: 577 (Растений: 557, Травоядных: 15, Хищников: 5)
# d d P d d d d P . d d d d d . d d d d d
# d . . d d d d d d d d . . d d P d d d d
# d d d d d . d d d d d d P d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d P d d d d d . P d d . d d d
# d d d d d d . . d d d d d d d d d . d d
# d d d d d d d d d d d d l L d d d P l d
# d d d d d d d d d m d d d L L L . L L L
# d d d l d d d d d d . d L L L l m L L L
# d d d d . P . d . d d L L L L L l L L L
# d d d d d d P . . P d d d l L L L L L L
# d d d . d d d d d d d d d d L L o o o o
# d . P d . P d d d d d d d d d d d d o o
# d . P . . d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d . d d d d d d
# . P d d P . d d d d d d m d d d d d d d
# d d d d . d d d d d d d d o d d d d d d
#
# День: 1 Время: День (Шаг: 32)
# Существ: 580 (Растений: 560, Травоядных: 15, Хищников: 5)
# d P . d d d d . P d d d d d . d d d d d
# d . . d d d d d d d d . P d P . d d d d
# d d d d d . d d d d d d . d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d . d d d d d . . P d . d d d
# d d d d d d P . l d d d d d d d d P d d
# d d d d d d d d d d d d L L l d d . L d
# d d d d d d d d d m l l l L L L l L L L
# d d d L d d d d d d . d L L L L m L L L
# d d d . l . P d . d d L L L L L L L L L
# d d d d P l . . . . d d l L L L L L L L
# d d d . d d d d P d d d d d L L l l o o
# d . . d . . d d d d d d d d l d d d o o
# d . P . P d d d d d d d d d d d d d d d
# d P d d d m d d d d d d d . d d d d d d
# . P d d . . d d d d d d m d d d d d d d
# d d d d P d d d d d d d d o d d d d d d
#
# День: 1 Время: День (Шаг: 33)
# Существ: 586 (Растений: 566, Травоядных: 15, Хищников: 5)
# d . . d d d d P . d d d d P . d d d d d
# d P . d d d d d d d d . . d . . d d d d
# d d d d d . d d d d d d . d d P d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d P d d d d
# d d d d d d l d d d d d . . . d . P d l
# d d d d d d . l L d d d d d d d d . d d
# d d d d d d P d l l d d L L L d d . L d
# d d d d d d d d d m L L L L L L L L L L
# d d d L d d d d d d l l L L L L m L L L
# d d d l L P . d . d d L L L L L L L L L
# d d d l . L l . . . d d L L L L L L L L
# d d d P d d d d P d d d d l L L L L l o
# d P . d . P d d d d d d d d L l d d l o
# d . . . . d d d d d d d d d d d d d d d
# d P d d d m d d d d d d d . d d d d d d
# . P d d . . d d d d d d m d d d d d d d
# d d d d P d d d d d d d d o d d d d d d
#
# День: 1 Время: День (Шаг: 34)
# Существ: 588 (Растений: 568, Травоядных: 15, Хищников: 5)
# d . . d d d d . P d d d d . . d d d d d
# d P . d d d d d d d d . P d . . d d d d
# d d d d d . d d d d d d . d d P d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d l d d d d d d P d d d
# d d d d d d d d d d d d d d d . P d d d
# d d d d d d L l d d d d . . . d . . l L
# d d d d d d l L L d d d d d d d d . d d
# d d d d d . . d L L d d L L L l l . L d
# d d d d d P d d d m L L L L L L L L L L
# d d d L . P d d d d L L L L L L m L L L
# d d d L L . l d . d d L L L L L L L L L
# d d d L l L L l . P d d L L L L L L L L
# d P d . P l d d . d d d d L L L L L L o
# d . . d P . d d d d d d d d L l d l L o
# d . . . . d d d d d d d d d d d d d d d
# d . P d d m d d d d d d d . d d d d d d
# P . d d P . d d d d d d m d d d d d d d
# d d d d . d d d d d d d d o d d d d d d
#
# День: 1 Время: День (Шаг: 35)
# Существ: 595 (Растений: 575, Травоядных: 15, Хищников: 5)
# d . . d d d d P . d d d d . . d d d d d
# d . . d d d d d d d d P . d . . d d d d
# d d P d d . d d d d d d . d d P d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d L d d d d d d P d d d
# d d d d d d d l l d d d d d d P . d d d
# d d d d d d L L d d d d . . . d . l L L
# d d d d d d L L L d l l l d d d d l d d
# d d d d d l l l L L d l L L L L L . L d
# d d d d d P d d d m L L L L L L L L L L
# d d d L l . P d d d L L L L L L m L L L
# d d d L L l L d . d d L L L L L L L L L
# d d d L l L L L . P d d L L L L L L L L
# d . d . . L d d . d d d d L L L L L L o
# d . P d P P d d d d d d d d L L d L L o
# d P . . . d d d d d d d d d d d d d d d
# d P . d d m d d d d d d d . d d d d d d
# . . d d P . d d d d d d m d d d d d d d
# d d d d . d d d d d d d d o d d d d d d
#
# День: 1 Время: Вечер (Шаг: 36)
# Существ: 619 (Растений: 599, Травоядных: 15, Хищников: 5)
# D d d D D D D . P D D D D . d D D D D D
# D . d D D D D d d d d . d D d d d D D D
# d d P D d d D d D d d D P D D P D D D D
# D D d . d . d d D D D D D D d D D D D D
# D D D D M D D D d D D d D d D D D d D D
# D D D D D D D D D l D D D D P D . P d D
# D D D D d D D l l D D D d D D . d d D D
# D D D D D D l l d d D D d . d d d d l l
# D D D D D D l l l D l l l d D D D l d D
# D d D D D l l l l l D l l l l l l d l d
# D d D D D . P d d . l l l l l l l l l l
# d D d l P d . D D . M l l l l l M l l l
# D D d l l l l d d D d l l l l l l l l l
# D D D l l l l l . P D d l l l l l l l l
# D d P d d l d D d D D D D l l l l l l o
# D d . D . . D D d D D D D D l l D l l o
# D . P P d P D D D D d d D D D D d D D D
# D . d D P . d d d D D . d d D D D D D D
# . d P D . M D d d d D D M d d D d D D D
# D D D D d D D D D D D D D d D D D D D D
#
# День: 1 Время: Вечер (Шаг: 37)
# Существ: 639 (Растений: 619, Травоядных: 15, Хищников: 5)
# D d D D D D D d P D D D D d d D D D D D
# D d d P D D D d D D d d d D d D d D D D
# D d . D d d D D D d d D P D D . P D D D
# D D D M d d D D D D D D D D D D D D D D
# D D D D . D D D d D D d D D D D D D D D
# D D D D D D D D D l D D D P . D d P d D
# D D D D D D D d l D D D d D D d D d D D
# D D D D D D l d D d D D d . D d d d d l
# D D D D D D l l l D l l l D D D D l D D
# D d D D D l l d l l D l l l l l l D l D
# D d D D D d . D D d l l l l l l l l l l
# d D d l P P d D D d M l l l l l M l l l
# D D d l d d d d D D D . l l l l l l l l
# D D D d d d l l d . P D l l l l l l l l
# D d . P D d d D d D D D D l l l l l l o
# D D d D d d D D d D D D D D l l D l l d
# D d . P P P D D D D d d D D D D d D D D
# D d P D . d D d d D D d D D D D D D D D
# d D P D d . M D d D D M . D D D D D D D
# D D D D d D D D D D D D D D D D D D D D
#
# День: 1 Время: Вечер (Шаг: 38)
# Существ: 650 (Растений: 630, Травоядных: 15, Хищников: 5)
# D D D D P D D D P D D D D D d D D D D D
# D d d . D D D d D D d d D D D D d D D D
# D D d D D d D D D d d D P D D d P D D D
# D D D . M d D D D D D D D D D D D D D D
# D D D D d D D D D D D D P D D D D D D D
# D D D D D D D D D d D D D . d D d P D D
# D D D D D D D d d D D D d D D d D d D D
# D D D D D D d d D D D D D d D D d D d d
# D D D D D D d d l D d l l D D D D d D D
# D d D D D d d D d l D l l l l l l D l D
# D d D D P d d D D D l l l l l l l l l l
# D D d l . . P D D D . . l l l l M l l l
# D D D d d d d D D D M P l l l l l l l l
# D D P d d d d d d d . D l l l l l l l l
# D D d . D D D D d D D D D l l l l l l o
# D D P D P D D D D D D D D D l l D l l D
# D P d P . . D D D D d D D D D D D D D D
# D d . D d d D d D D M d D D D D D D D D
# D D P D d M . D D D D . d D D D D D D D
# D D D D d D D D D D D D D D D D D D D D
#
# День: 1 Время: Вечер (Шаг: 39)
# Существ: 662 (Растений: 642, Травоядных: 15, Хищников: 5)
# D D D D P D D D P D D D D D d D D D D D
# D D d d D D D d D D d d D D D D d P D D
# D D d D D d D D D d d D . D D D . D D D
# D D D d . D D D D D D P P D D D D D D D
# D D D M D D D D D D D D . D D D D D D D
# D D D D D D D D D d D D D d d D D P D D
# D D D D D D D d D D D D D D D d D d D D
# D D D D D D d D D D D D D d D D d D d d
# D D D D D D d d d D D d l D D D D d D D
# D D D D D d D D d d D l l l d l d D d D
# D D D D . P P D D D l l l l l l l l d l
# D D d d d d . D D D P . l l l l M l l l
# D D D d d D d D D D . M l l l l l l l l
# D D . d d d D d d d d D d l l l l l l l
# D D P P D D D D d D D D D l l l l l l o
# D P . D P D D D D D D D D D d d D l l D
# D . P . d d D D D D d D D D D D D D D D
# D d d D d d D d D D M D D D D D D D D D
# D D . D d . M D D D D d d D D D D D D D
# D D P D D D D D D D D D D D D D D D D D
#
# День: 1 Время: Вечер (Шаг: 40)
# Существ: 674 (Растений: 654, Травоядных: 15, Хищников: 5)
# D D D D P D D P . D D D D D D D D D D D
# D D D d D D D d D D d d D D D D d . D D
# D D d D D D D D D d d D d D D D d D P D
# D D D M d D D D D D P P . D D D D D D D
# D D D . D D D D D D D D d D D D D D D D
# D D D D D D D D D D D D D d d D D P D D
# D D D D D D D D D D D D D D D d D d D D
# D D D D D D D D D D D D D d D D d D d D
# D D D D D D d d d D D D d D D D D D D D
# D D D D D P D P d D D l l d D l D D D D
# D D D D d . . D D D d l l l l l l . D l
# D D d d d d d D D D . . l l l l M l l l
# D D D d d D d D D D d P l l l l l l l l
# D D P d d D D d d d M D D l l l l l l l
# D D . . D D D D d D D D D l l l l l l o
# D P d P . P D D D D D D D D D D D l l D
# D d . d d d D D D D M D D D D D D D D D
# D d P D d d D D D D . D D D D D D D D D
# D P d D d d . M D D D d d D D D D D D D
# D D . D D D D D D D D D D D D D D D D D
#
# День: 1 Время: Вечер (Шаг: 41)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# D D D D P D P . . D D D D D D D D D D D
# D D D d D D D d D D d d D D D D d d D D
# D D d D D D D D D d d D d D D D d D . P
# D D D . d D D D D D . P d D D D D D D D
# D D M d D D D D D D D P d D D D D D P D
# D D D D D D D D D D D D D D D D D . D D
# D D D D D D D D D D D D D D D d D d D D
# D D D D D D D D D D D D D d D D d D d D
# D D D D D D d d d D D D D D D D D D D D
# D D D D D . D . d D D d l D D d D D D D
# D D D D D . P D P D D l l l l l l M D l
# D D d d D d d D D D d d l l l l . l l l
# D D D d d D d D D D d . l l l l l l l l
# D D P d d D D D D d M P D l l l l l l l
# D D P d D D D D d D D D D d l l l l l o
# D . d . P . D D D D D D D D D D D d d D
# D P P d d d D D D D M D D D D D D D D D
# D d . D d d D D D D d D D D D D D D D D
# D P d D D d d M D D D D D D D D D D D D
# D D d D D D D D D D D D D D D D D D D D
#
# День: 1 Время: Ночь (Шаг: 42)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d . p
# d d d . d d d d d d . p d d d d d d d d
# d d m d d d d d d d d p d d d d d d p d
# d d d d d d d d d d d d d d d d d . d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d . d d d d l d d d d d d d
# d d d d d . p d p d d l l l l l l m d l
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l l O
# d . d . p . d d d d d d d d d d d d d d
# d p p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 1 Время: Ночь (Шаг: 43)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d . p
# d d d . d d d d d d . p d d d d d d d d
# d d m d d d d d d d d p d d d d d d p d
# d d d d d d d d d d d d d d d d d . d d
# d d d d d d d d d d d d o d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d . d d d d l d d d d d d d
# d d d d d . p d p d d l l l l l l m d o
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l l O
# d p d . p . d d d d d d d d d d d d d d
# d . p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 1 Время: Ночь (Шаг: 44)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d . p
# d d d . d d d d d d . p d d d d d d d d
# d d m d d d d d d d d p d d d d d d p d
# d d d d d d d d d d d d o d d d d . d d
# d d d d d d d d d d d d O d d d d d d d
# d d d d d d d d d d d d d o d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d . d d d d l d d d d d d d
# d d d d d . p d p d d l l l l l l m d O
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l l O
# d p d . p . d d d d d d d d d d d d d d
# d . p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 1 Время: Ночь (Шаг: 45)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d . p
# o d d . d d d d d d . p d d d d d d d d
# d d m d d d d d d d d p o d d d d d p d
# d d d d d d d d d d d d O d d d d . d d
# d d d d d d d d d d d d O d d d d d d d
# d d d d d d d d d d d d d O d d d d d d
# d d d d d d d d d d d o d d d d d d d d
# d d d d d . d . d d d d l d d d d d d d
# d d d d d . p d p d d l l l l l l m d O
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l l O
# d p d . p . d d d d d d d d d d d d d d
# d . p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 1 Время: Ночь (Шаг: 46)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# o d d d d d d d d d d d d d d d d d . p
# O d o . d d d d d d . p d d d d d d d d
# o d m d d d d d d d d p O d d d d d p d
# d d d d d d d d d d d o O d d d d . d d
# d d d d d d o d d d d o O d d d d d d d
# d d d d d d d d d d d d o O d d d d d d
# d d d d d d d d d d d O d d d d d d d d
# d d d d d . d . d d d d o d d d d d d d
# d d d d d . p d p d d l l l l l l m d O
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l o O
# d p d . p . d d d d d d d d d d d d d d
# d . p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 1 Время: Ночь (Шаг: 47)
# Существ: 687 (Растений: 667, Травоядных: 15, Хищников: 5)
# d d d d p d p . . d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# O o d d d d d d d d d d d d d d d d . p
# O d O . d d d d d d . p d d d d d d d d
# O o m d d d d d d d d p O d d d d d p d
# d d d d d d o d d d d O O d d d d . d d
# d d d d d d O d d d d O O o d d d d d d
# d d d d d d d d d d d d O O d d d d d d
# d d d d d d d d d d d O o o d d d d d d
# d d d d d . d . d d d d O d d d d d d d
# d d d d d . p d p d d l l l l l l m d O
# d d d d d d d d d d d d l l l l . l l l
# d d d d d d d d d d d . l l l l l l l l
# d d p d d d d d d d m p d l l l l l l l
# d d p d d d d d d d d d d d l l l l O O
# d p d . p . d d d d d d d d d d d d o d
# d . p d d d d d d d m d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d p d d d d d m d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 2 Время: Утро (Шаг: 48)
# Существ: 694 (Растений: 674, Травоядных: 15, Хищников: 5)
# D d D D . D P d d D D D D D D d D D D D
# D d d d P D D d d d d d d D d d d d D D
# o d d D D d d d D d d D d D D d d D . P
# o . o d d d D D D D P P d D D D D d D D
# o o M d d D d D d D d . o d D D D D P D
# D D d D D D o D d d D o o d d D d d d D
# D D D D D D o d D D D o o d d d D D D d
# D D D D d D d d D D D D o o d D d d D D
# D D D D D D d d D D D o o o D D D D d D
# D d D D D d D d d D D D o D D d D D d D
# D d D D d d P D . P D l l l l d l . D o
# d d d d D d d D D d D D . l l l M l l l
# D d d d d d d D D . D d P l l l l l l l
# D D . d d D D d d D M . D d l l l l l l
# D P . P D d D D D d D D D D l d l l o o
# D P d d . d D D d . d D D D D D D D o D
# D d . d D P D . D D M d d D D D D D D D
# P P . D D d D d M D d d D D D D D D D D
# D . d D d d D . d D D D d D D D D D D D
# D D d D D D D D D D D D D D D D D D D D
#
# День: 2 Время: Утро (Шаг: 49)
# Существ: 709 (Растений: 689, Травоядных: 15, Хищников: 5)
# D D D D d D . D d D D D D D D d D D D D
# D d d P . P D d d d d d D D D D d D D D
# d D d D D D d d D d d D d D D d d D d .
# o d M D d d D D D D . . D D D D D P D P
# o o . d d D d D D P P d o d D D D D . D
# D D D D D D d D D d D o o D d D D d d D
# D D D D D D d D D D D d o d d d D D D D
# D D D D d D D d D D D D o o d D d d D D
# D D D D D D d d D D D o o d D D D D d D
# D d D D D d D d D D P D o D D D D D d D
# D d D D d D P D d . D d l l d D . . D o
# d d d d D d d D D D D D . l l l . M l l
# D d d d D d d D D d D P . l l l l l l l
# D D P d d D D d d D M d D D d l l l l l
# D . d P D d D D D d D D D D d D d d o o
# D P d d d d P D d d d D D D D D D D o D
# P d d d D . D d D D M d D D D D D D D D
# . P d D D D D d . D D d D D D D D D D D
# D d d D d d D d M D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
#
# День: 2 Время: Утро (Шаг: 50)
# Существ: 722 (Растений: 702, Травоядных: 15, Хищников: 5)
# D D D D D D d D D D D D D D D D D D D D
# D d P . d P D d d d d d D D D D d D D D
# D D d M D D D D D D d D d D D d D D d d
# d d . D d d D D P P d d D D D D D . D .
# o d d d d D d D D . . D d D D D D D P P
# D D D D D D d D D D D d d D d D D d d D
# D D D D D D d D D D D D d d d d D D D D
# D D D D D D D d D D D D d d D D d d D D
# D D D D D D d d D D D o d d D D D D d D
# D D D D D d P d D D . P o D D D D D D D
# D D D D d D . D D d D D . l D D d M D o
# D d d D D d d D D D D D P l l l d . l l
# D d d d D d D D D d D . d l l l l l l l
# D D P d d D D D D D M D D D D l l l l l
# D d d . P D D D D d D D D D D D D D o o
# D . P d D d . D d M d D D D D D D D o D
# P d P d D d D P D D . D D D D D D D D D
# d . d D D D D d d D D d D D D D D D D D
# D d d D d d D D . D D D D D D D D D D D
# D D D D D D D D D M D D D D D D D D D D
#
# День: 2 Время: Утро (Шаг: 51)
# Существ: 738 (Растений: 718, Травоядных: 15, Хищников: 5)
# D D D P D D P D D D D D D D D D D D D D
# D d M d d . D d D d d d D D D D D D D D
# D D d . D D D D D D d D d D D d D D D D
# d d d D d d D D P P d d D D D D D d D d
# d D d D d D D D D d d D D D D D D D P P
# D D D D D D d D D D D d D D d D D d d D
# D D D D D D d D D D D D d d d d D D D D
# D D D D D D D d D D D D d D D D d d D D
# D D D D D D d d D D D d D d D D D D d D
# D D D D D d P d D D d . o D D D D D D D
# D D D D D D d D D D P D d l D D D . D o
# D d d D D d d D D D D D P l l l D M d d
# D d d d D d D D D d D d D l l l l l l l
# D D P d d D D D D D . D D D D l l l d l
# D D d d P D D D D M D D D D D D D D o o
# D d . d D d P D M . d D D D D D D D d D
# P d P P D d D . D D d D D D D D D D D D
# d d d D D D D d d D D d D D D D D D D D
# D d d D D d D D d D M D D D D D D D D D
# D D D D D D D D D . D D D D D D D D D D
#
# День: 2 Время: Утро (Шаг: 52)
# Существ: 746 (Растений: 726, Травоядных: 15, Хищников: 5)
# D D M . P D . D D D D D D D D D D D D D
# D D . D D d D P D d d d D D D D D D D D
# D D d d D D D P P D d D d D D d D D D D
# D d d D d d D D . . d d D D D D D d D D
# D D d D d D D D D d d D D D D D D D P P
# D D D D D D D D D D D D D D D D D d d D
# D D D D D D D D D D D D d d D d D D D D
# D D D D D D D d D D D D d D D D d d D D
# D D D D D D d D D D D D D d D D D D d D
# D D D D D d P d D D d P d D D D D D D D
# D D D D D D d D D D . D D d D D D d M d
# D d d D D d d D D D D P . l l l D . D D
# D d d d D D D D D d D d D l l l l l l l
# D D . P P D D D D D d D D D D d l d D l
# D D d d . D D D D M M D D D D D D D o o
# D d d d D d P D . d d D D D D D D D D D
# . d P . D d D d D D d D D D D D D D D D
# D P P D D D D d d M D d D D D D D D D D
# D d d D D d D D D D . D D D D D D D D D
# D D D D D D D D D d D D D D D D D D D D
#
# День: 2 Время: Утро (Шаг: 53)
# Существ: 760 (Растений: 740, Травоядных: 15, Хищников: 5)
# D D M P . D d D D D D D D D D D D D D D
# D D d D D d D . D d d d D D D D D D D D
# D D d d D D D P P D d D d D D d D D D D
# D d d D d d P D d d d d D D D D D D D D
# D D d D d D D D D d d D D D D D D P . P
# D D D D D D D D D D D D D D D D D d D D
# D D D D D D D D D D D D d d D d D D D D
# D D D D D D D d D D D D D D D D d d D D
# D D D D D D d D D D D D D D D D D D D D
# D D D D D d . d D D d . D D D D D D D D
# D D D D D D d P D D d P D D D D D D . D
# D d d D D d d D D D D P d d l l D d D M
# D d d d D D D D D d D d D l l l d l l l
# D D d P P D D D D D d D D D D D l D D l
# D D d d d P D D D M . D D D D D D D d d
# D d d d D d . D d M d D D D D D D D D D
# d d P d D d D D D D d D D D D D D D D D
# D . . D D D D d d M D d D D D D D D D D
# D P P D D d D D D D d D D D D D D D D D
# D D D D D D D D D d D D D D D D D D D D
#
# День: 2 Время: День (Шаг: 54)
# Существ: 761 (Растений: 741, Травоядных: 15, Хищников: 5)
# d d m P . d d d d d d d d d d d d d d d
# d d d d d d d . P d d d d d d d d d d d
# d d d d d d d . P d d d d d d d d d d d
# d d d d d d P d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d P . P
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d . l d d d l d d d d d d d d
# d d d d d d d . d d d . d d d d d d . d
# d d d d d d P d d d d P d d l L d d d m
# d d d d d d d d d d P d d L L l d L L L
# d d P . P d d d d d d d d d d d l d d L
# d d d d d . d d d m . d d d d d d d d d
# d d d d d d P d d m d d d d d d d d d d
# d d P d d d d d d d d d d d d d d d d d
# d P P d d d d d d m d d d d d d d d d d
# d . . d d d d d d d d d d d d d d d d d
# ...
# D d d d d d d d d d D D d D D d D D D D
# D D D d d d d d d d d D D D D D D d D D
# D D d d d D d d d d D d D d D D D d D D
# D D D d D d d d d d D d D d D D d d d D
# D d D D d d d d d d d d d d D D d d D D
# D d d d D d d d d d d d d d D D d D d D
# D d d d d d d d d d d d d d d D D D d D
# D d d d d d d d d d d d M D D D d D d D
# d d d d d . d d d d d d d D D l D D D D
# . d d D M d d d d d d d d d d d d d d d
# P d d d d d d d d d d d d d d d d l d D
# d d d d d d d d d d d d d d D D D l D D
# D d d P d d d d d d d d d d d d d D D D
# d d . d d d d d d d d d d d D D D D D D
# d d P d d d d d D d d d . d D D D D D D
# d d d d . M d d d d d d M d d D D D D D
# d d d P d d d D d d M d d M . D D D D D
# d d d d D D d D D d d d d D d D D D D D
#
# День: 7 Время: Вечер (Шаг: 184)
# Существ: 1451 (Растений: 1441, Травоядных: 4, Хищников: 6)
# D d d d d d d D d D D D d D D D D D D D
# d d d d d d d d d d d D d D D D D d D D
# D d D d d d d d d d D D d D D d D D D D
# D D D d d d d d d d d D D D D D D d D D
# D D d d d D d d D d D d D d D D D d D D
# D D D d D d d d d d D d D d D D d d d D
# D D D D D d d d d D d d d d D D D d D D
# D d d d D d d d d d d d d d D D d D d D
# D d d d d d d d d d d d d D d D D D d D
# D d d d d d d d d d d d M D D D d D D D
# d d d d d d d d d d d d d D D d D D D D
# d P d D . d d d d d d d d d d d D d d D
# . d d M d d d d d d d d d d d d D l D D
# d d P d d d d d d d d d d d D D D l D D
# D d d . d d d d d d d d d d d d D D D D
# d d d d d d d d d d d d d d D D D D D D
# d d P d d d d d D d d d d d D D D D D D
# d d d d P . d d d d d M . M d D D D D D
# d d d . M d d D d d . d d M d D D D D D
# d d d d D D d D D D d D d D d D D D D D
#
# День: 7 Время: Вечер (Шаг: 185)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# D d d d d d d D d D D D D D D D D D D D
# d d d d d d d d d d d D d D D D D D D D
# D d D d d d d d d d D D d D D D D D D D
# D D D d d d d d d d d D D D D D D d D D
# D D d d d D d d D d D d D d D D D d D D
# D D D d D d d d d d D d D D D D d d d D
# D D D D D d D d d D d d d d D D D d D D
# D d d d D d d d d d d d d d D D d D d D
# D d D d d d d d d d d d d D d D D D d D
# D d d d d d d d d d d d . D D D D D D D
# d d d d d d d d d d d d d M D d D D D D
# d . d D d d d d d d d d d d d d D d D D
# P d d . d d d d d d d d d d d d D d D D
# d d . M d d d d d d d d d d D D D l D D
# D d d P d d d d d d d d d d d d D D D D
# d d d P d d d d d d d d d D D D D D D D
# d d . d d d d d D d d d d d D D D D D D
# d d d d M P d d d d d . M M d D D D D D
# d d d d . d d D d d d d d M d D D D D D
# d d d d D D d D D D d D d D D D D D D D
#
# День: 7 Время: Ночь (Шаг: 186)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d o d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d o d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d . d d d d d d d d d d d d d d d d d d
# p d d . d d d d d d d d d d d d d d d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d . m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 187)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d o d d d d O d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d O d d d d d d d d d d d d
# d d d d d d d d d d d o d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d . d d d d d d d d d d d d d d d d d d
# p d d . d d d d d d d d d d d d d d d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d . m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 188)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d o d d d d d d d d d d d d d d d d d
# o d o d d d d d d d d d d d d d d d d d
# d d O d d d d O d d d d d d d d d d d d
# d d d d d d d d o d d d d d d d d d d d
# d d d d d d d O o d d d o d o d d d d d
# d d d d d d d d d d d O d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d . d d d d d d d d d d d d d d d o d d
# p d d . d d d d d d d d d d d d d d d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d . m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 189)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d o O d d d d d d d d d d d d d d d d d
# O d O d d d d d d d d d d d d d d d d d
# d d O d d d d O d d d o d d d d d d d d
# d d d d d d d o O d d o d d d d d d d d
# d d d d d d d O O o d d O d O d d d d d
# d d d d d d d d d d d O d d d d d d d d
# d d d d d d d d d d d d d d d d d d o d
# d d d d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d . d d d d d d d d d d d d d d d O d d
# p d d . d d d d d d d d d d d d d d d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d . m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 190)
# Существ: 1457 (Растений: 1447, Травоядных: 4, Хищников: 6)
# d d d d d d d d d d d d d d d d d d d d
# d o d d d d d d d d d d d d d d d d d d
# o O O d d d d d d d d d d d d d d d d d
# O o O d d d d o d o d d d d d d d d d d
# o d O d d d o O o d d O d d d d d d d d
# d d d d d d d O O d o O o o d d d d d d
# d d d d d d o O O O d o O d O d d d d d
# d d d d d d d d d d o O o o d d d d d d
# d d d d d d d d d d d d d d d d d d O d
# d d d d d d d d d d d d . d d d d o o d
# d d d d d d d d d d d d d m d d d d d d
# d . d d d d d d d d d d d d d d d O d d
# p d d . d d d d d d d d d d d d d d d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d . m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 191)
# Существ: 1458 (Растений: 1447, Травоядных: 4, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d d
# o O o d d d d d d d d d d d d d d d d d
# O O O d d d o d d d d d d d d d d d d d
# O O O o d d d O d O d d d d d d d d d d
# O o O d d d O O O d d O d d d d d d d d
# d d d d d d o O O d O O O O o d d d d d
# d d d d d d O O O O o O O o O d d d d d
# d d d d d d d d o d O O O O o d d d d d
# d d d d d d d d d d d o o o d d d d O o
# d d d d d d d d d d d d . d d d d O O d
# d d d d d d d d d d d d d m d d d d o d
# d . d d d d d d d d d d d d d d d O d d
# p d d . d d d d d d d d d d d d d o d d
# d d . m d d d d d d d d d d d d d l d d
# d d d p d d d d d d d d d d d d d d d d
# d d d p d d d d d d d d d d d d d d d d
# d d . d d d d d d d d d d d d d d d d d
# d d d d m p d d d d d M m m d d d d d d
# d d d d . d d d d d d d d m d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 8 Время: Утро (Шаг: 192)
# Существ: 1458 (Растений: 1447, Травоядных: 4, Хищников: 7)
# D d d d d d d d d D d d d D D D d D D D
# d o d d d d d d d d d d d D d d d d D D
# o o o d d d d d d d d D d D D d d D d D
# o o o d d D d o d o d d D D D D d d d d
# o o o d d D o o o d d o d d D D D d D D
# D D d d d d d o o d o o o o o D d d D D
# D d d D d d o o o o d o o o o d d d d D
# d d D d d d d d d d o o o o d d d d d D
# d d d d d d d d d d d d d d d D d d o o
# d d d d d d d d d d d d d D D D d o o D
# d d d d d d d d d d d . d . d d d d o d
# d P d d d d d d d d d d M d d d D o d D
# . d . d d d d d d d d d d d d d d o D D
# d d d M d d d d d d d d d d d D D d D D
# d d d . d d d d d d d d d d d d D D D D
# d d d P P d d d d d d d d . D D D D D D
# d d d d P d d d d d d . d d M D D D D D
# d d . d . . d d d d d . M . d D D D D D
# d d d M d d d d d d d d M . d D d D D D
# d d d d d D d D D d d d d M D D D D D D
#
# День: 8 Время: Утро (Шаг: 193)
# Существ: 1471 (Растений: 1460, Травоядных: 4, Хищников: 7)
# D d d d d d d d d D d d d D D D d D D D
# D d d d d d d d d d d d d D d d d D D D
# o d d d d d d d d d d D d D D D d D d D
# o o o D d D d d d d d d D D D D d d d d
# o o d d d D d d d d D d d d D D D d D D
# D D d d d d d d d d d d d o d D d d D D
# D d d D D d d d d d d d o d d d d d d D
# d d D d D d d d d d d d d d D d d d d D
# d d d d d d d d d d d d d D D D d d d d
# d D d d d d d d d d d d d D D D d o d D
# P d d d d d d d d d d d d d d D D d o d
# d . d d d d d d d d d M . d d d D o d D
# d d d d d d d d d d d d d d d d D o D D
# d d d M d d d d d d d d d d d D D d D D
# d d d d d d d d d d d d d d d D D D D D
# d d d . P P d d d d d d d d D D D D D D
# d d d d P d d d d d d M d d M D D D D D
# d d M d d d d d d d d d . d d D D D D D
# d d d . d d d d d d d d M M D D D D D D
# d d d d d D D D D d d d d . D D D D D D
#
# День: 8 Время: Утро (Шаг: 194)
# Существ: 1477 (Растений: 1466, Травоядных: 4, Хищников: 7)
# D d d d d d d d d D d D d D D D d D D D
# D d d d d d d d d d d d D D D d d D D D
# d D d d d d d d d d d D d D D D d D D D
# o d d D d D d d d d d d D D D D d d d d
# o o d d d D d d d d D d d D D D D d D D
# D D D d d d d d d d d d d d D D D d D D
# D d d D D d d d d D d d d d d D d D d D
# d d D d D d d d d d d d d d D d d d d D
# d d d d d d d d d d d d d D D D D d d d
# P D d d d d d d d d d d d D D D D d d D
# . d d d d d d d d d d d M d d D D d d D
# d d d d d d d d d d d . d d d d D o D D
# d d d d d d d d d d d d d d d D D o D D
# d d d . M d d d d d d d d d d D D D D D
# d d d P d P d d d d d d d d d D D D D D
# d d d d P . d d d d d d d d D D D D D D
# d d d d . d d d d d M . d d . D D D D D
# d d . M d d d d d d d M d d M D D D D D
# d d d d d d d d d d d d . . D D D D D D
# d d d d d D D D D d d d d M D D D D D D
#
# День: 8 Время: Утро (Шаг: 195)
# Существ: 1487 (Растений: 1476, Травоядных: 4, Хищников: 7)
# D D d d d d d d D D D D d D D D D D D D
# D d d d d d d d d d d d D D D d d D D D
# D D d d d d d d d d d D d D D D d D D D
# d d d D d D d d d d d d D D D D d D d D
# o d d d d D d d d d D D d D D D D d D D
# D D D d d d D d d d d d d d D D D d D D
# D d d D D d d d d D d d d d D D d D d D
# D d D d D d d d d d d d D d D d D d d D
# d d d d d d d d d d d d d D D D D d d d
# P D d d d d d d d d d d d D D D D d d D
# d d d d d d d d d d d d M d d D D D D D
# d d d d d d d d d d d d d d d d D d D D
# d d d M d d d d d d d d d d d D D d D D
# d d P d P d d d d d d d d d d D D D D D
# d d d . d . d d d d d d d d d D D D D D
# d d d d P d d d d d d d d d D D D D D D
# d d d d d d d d d d . M d d d D D D D D
# d d d . d d d d d d d . M d M D D D D D
# d d M d d d d d d d d d d d D D D D D D
# d d d d d D D D D d d d d M D D D D D D
#
# День: 8 Время: Утро (Шаг: 196)
# Существ: 1492 (Растений: 1481, Травоядных: 4, Хищников: 7)
# D D d d d d d d D D D D d D D D D D D D
# D d d d d d d d d d d d D D D D d D D D
# D D d d d d d d d d d D d D D D d D D D
# D d d D d D d d d d d d D D D D d D d D
# d D D d d D d d d d D D d D D D D d D D
# D D D d D d D d d d d d d d D D D d D D
# D d d D D d d d d D d d d d D D d D d D
# D d D d D d d d d d d d D d D d D d d D
# d d d d d d d d d d d d d D D D D D d D
# . D D d d d d d d d d d d D D D D d d D
# P d d d d d d d d d d d M d d D D D D D
# d d M d d d d d d d d d d d d d D D D D
# d d d . d d d d d d d d d d d D D D D D
# d d . d . d d d d d d d d d d D D D D D
# d d d P d P d d d d d d d d d D D D D D
# d d d d . d d d D d d d d d D D D D D D
# d d d d d P d d d d d . d M D D D D D D
# d d d d d d d d d d M d . M . D D D D D
# d d . M d d d d d d d d M d D D D D D D
# D d d d d D D D D d d d d . D D D D D D
#
# День: 8 Время: Утро (Шаг: 197)
# Существ: 1502 (Растений: 1491, Травоядных: 4, Хищников: 7)
# D D d d D d d d D D D D D D D D D D D D
# D d d d d d d d d d d d D D D D d D D D
# D D d d d d d d d d d D d D D D D D D D
# D d D D d D d d d d d d D D D D D D d D
# D D D d d D d d d d D D d D D D D d D D
# D D D d D d D d d d d d D d D D D d D D
# D d d D D d d d d D d d d d D D d D d D
# D D D d D d d d d d d d D d D d D d d D
# d d d d d d d d d d d d d D D D D D d D
# P D D d d d d d d d d d d D D D D d d D
# . d d d d d d d d d d d . M d D D D D D
# d d . d d d d d d d d d d d d d D D D D
# d d M d d d d d d d d d d d d D D D D D
# d d d d d d P d d d d d d d d D D D D D
# d d d P d . d d d d d d d d d D D D D D
# d d d d d d d d D d d d d d M D D D D D
# d d d d d P d d d d d M M . D D D D D D
# d d d d M d d d d d . M d . d D D D D D
# d d d . d d d d d d d d . d D D D D D D
# D d d d d D D D D d d d d d D D D D D D
#
# День: 8 Время: День (Шаг: 198)
# Существ: 1500 (Растений: 1489, Травоядных: 4, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d l d d d d d d d d d d d
# d d d d d d d d l d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d l d l l d d d d d d d d
# . d d d l l d d l d d l l d d d d l d d
# P d d d d l l d d d d l l m d d d d d d
# d d . d l . d d l d l d l d d d d d d d
# d d m d d l P l d l l l d d d d d d d d
# d d d d l l . d d l l d l l d d d d d d
# d d . P d . l d d d d l d l d d d d d d
# d d d d d d d l d d d d d d m d d d d d
# d d d . P . d d d d d m m . d d d d d d
# d d d d m l d d d d . m d . d d d d d d
# d d d . d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 8 Время: День (Шаг: 199)
# Существ: 1503 (Растений: 1492, Травоядных: 4, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d l L l d d d d d d d d d d
# d d d d d d d d L l d d d d d d d d d d
# d d d d d d l d d l d d d d d d d d d d
# d d d d l d d d L l L L l d d d d d d d
# . d d d L L l l L l l l l d d d l L d d
# . d d l d L L d l l l L l m d d d d d d
# d P . l . l l d L d L l l d d d d d d d
# d d m l l P . L d L L L l l l d d d d d
# d d d d l l l d d L L l L L d d d d d d
# d d l . l l L d d d l L l L d d d d d d
# d d l P d d l L d d d d d d m d d d d d
# d d d l P . l l d d d m m . d d d d d d
# d d d l m L l d d d . m d . d d d d d d
# d d d . d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# День: 8 Время: День (Шаг: 200)
# Существ: 1507 (Растений: 1496, Травоядных: 4, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d L L l l d d d d d d d d d
# d d d d d d d d L L d d d d d d d d d d
# d d d d d d L l d L d d d d d d d d d d
# d d d d L d l d L L L L L d d d d d d d
# . d l l L L L L L L l L l l d d L L d d
# P d l L l L L l l l l L L m d d d d d d
# d . l L l L l l L l L l L l d d l d d d
# d d m l l P l L l L L L l l L l d l d d
# d d d l l l l d d L L L L L d d d d d d
# d d L l L L L d d l L L L L d d d d d d
# d d L . . l L L d d l d d d m d d d d d
# d d d L P P L L l d d m m . d d d d d d
# d d d L m L L d l d . m d . d d d d d d
# d d d . d l d d d d d d . d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
#
# Симуляция завершена.
# Итоговые показатели: День 8, Всего существ: 1507
# Растений: 1496
# Травоядных: 4
# Хищников: 7
