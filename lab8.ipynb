# %%
import random
import time
import unittest
from unittest import TestCase, TestLoader, TextTestRunner
from enum import Enum, auto
from typing import List, Dict, Tuple, Optional, Set

# %%
class TimeOfDay(Enum):
    MORNING = auto()  # Утро
    DAY = auto()      # День
    EVENING = auto()  # Вечер
    NIGHT = auto()    # Ночь

# %%
class World:
    def __init__(self, width: int, height: int):
        self.width = width
        self.height = height
        self.grid = [[None for _ in range(width)] for _ in range(height)]
        self.time_of_day = TimeOfDay.MORNING
        self.time_ticks = 0
        self.entities = []
        self.day_counter = 0

    def add_entity(self, entity, x: int, y: int):
        if not (0 <= x < self.width and 0 <= y < self.height):
            return False

        if self.grid[y][x] is not None:
            return False

        entity.x = x
        entity.y = y
        entity.world = self
        self.grid[y][x] = entity
        self.entities.append(entity)
        return True

    def remove_entity(self, entity):
        if entity in self.entities:
            self.entities.remove(entity)

        if (0 <= entity.x < self.width and
            0 <= entity.y < self.height and
            self.grid[entity.y][entity.x] == entity):
            self.grid[entity.y][entity.x] = None

    def get_neighbors(self, x: int, y: int) -> List[Tuple[int, int]]:
        neighbors = []
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                if dx == 0 and dy == 0:
                    continue
                nx, ny = x + dx, y + dy
                
                if 0 <= nx < self.width and 0 <= ny < self.height:
                    neighbors.append((nx, ny))
        return neighbors

    def update_time(self):
        self.time_ticks += 1
        if self.time_ticks % 6 == 0:
            prev_time = self.time_of_day
            self.time_of_day = {
                TimeOfDay.MORNING: TimeOfDay.DAY,
                TimeOfDay.DAY: TimeOfDay.EVENING,
                TimeOfDay.EVENING: TimeOfDay.NIGHT,
                TimeOfDay.NIGHT: TimeOfDay.MORNING
            }[self.time_of_day]
            
            if prev_time == TimeOfDay.NIGHT and self.time_of_day == TimeOfDay.MORNING:
                self.day_counter += 1

    def step(self):
        self.update_time()

        for entity in self.entities[:]:
            if isinstance(entity, Plant):
                entity.grow()
        
        for entity in random.sample(self.entities[:], len(self.entities[:])):
            if isinstance(entity, Animal):
                entity.update_behavior()  # Обновление поведения
                entity.move()            # Движение
                entity.eat()             # Питание
                entity.reproduce()       # Размножение
                entity.update_hunger()   # Обновление уровня голода

                if entity.energy <= 0:
                    self.remove_entity(entity)

    def display(self):
        time_names = {
            TimeOfDay.MORNING: "Утро",
            TimeOfDay.DAY: "День",
            TimeOfDay.EVENING: "Вечер",
            TimeOfDay.NIGHT: "Ночь"
        }
        print(f"День: {self.day_counter} Время: {time_names[self.time_of_day]} (Шаг: {self.time_ticks})")
        print(f"Существ: {len(self.entities)} (Растений: {sum(1 for e in self.entities if isinstance(e, Plant))}, "
              f"Травоядных: {sum(1 for e in self.entities if isinstance(e, Pauvre))}, "
              f"Хищников: {sum(1 for e in self.entities if isinstance(e, Malheureux))})")

        for y in range(self.height):
            row = []
            for x in range(self.width):
                entity = self.grid[y][x]
                if entity is None:
                    row.append('.')
                elif isinstance(entity, Lumiere):
                    row.append('L' if entity.active else 'l')
                elif isinstance(entity, Obscurite):
                    row.append('O' if entity.active else 'o')
                elif isinstance(entity, Demi):
                    row.append('D' if entity.active else 'd')
                elif isinstance(entity, Pauvre):
                    row.append('P' if not entity.sleeping else 'p')
                elif isinstance(entity, Malheureux):
                    row.append('M' if not entity.sleeping else 'm')
            print(' '.join(row))
        print()

# %%
class EcosystemMeta(type):
    
    _registry = {}
    
    def __new__(cls, name, bases, namespace):
        new_class = super().__new__(cls, name, bases, namespace)
        
        if name not in ['Plant', 'Animal']:
            cls._registry[name] = new_class
        
        if 'Plant' in [b.__name__ for b in bases]:
                new_class = cls._configure_plant(new_class, namespace)
        elif 'Animal' in [b.__name__ for b in bases]:
            new_class = cls._configure_animal(new_class, namespace)
            
        return new_class
    
    def __iter__(self):
        raise TypeError(f"'{self.__name__}' object is not iterable")    

    @classmethod
    def _configure_plant(cls, plant_class, namespace):
        
        # Получаем время роста из атрибутов класса
        growth_times = namespace.get('GROWTH_TIMES', [])
        
        # Динамически создаем метод can_grow_in_time
        def can_grow_in_time(self, time_of_day):
            return time_of_day in growth_times
            
        plant_class.can_grow_in_time = can_grow_in_time
        
        # Добавляем метод spread
        def spread(self):
            if not self.active:
                return
                
            neighbors = self.world.get_neighbors(self.x, self.y)
            random.shuffle(neighbors)
            
            for nx, ny in neighbors:
                target = self.world.grid[ny][nx]
                
                if target is None and random.random() < 0.2:
                    new_plant = self.__class__()
                    self.world.add_entity(new_plant, nx, ny)
                elif (isinstance(target, Plant) and 
                    target != self and 
                    self.active and not target.active and 
                    random.random() < 0.3):
                    target.health -= 20
                    if target.health <= 0:
                        self.world.remove_entity(target)
                        new_plant = self.__class__()
                        self.world.add_entity(new_plant, nx, ny)
        
        plant_class.spread = spread
        
        return plant_class
    
    @classmethod
    def _configure_animal(cls, animal_class, namespace):
        
        # Получаем параметры поведения из атрибутов класса
        food_types = namespace.get('FOOD_TYPES', [])
        sleep_times = namespace.get('SLEEP_TIMES', [])
        hunting_behavior = namespace.get('HUNTING_BEHAVIOR', {})
        
        # Динамически создаем метод get_food_types
        def get_food_types(self):
            return food_types
        
        # Динамически создаем метод modify_behavior
        def modify_behavior(self):
            self.sleeping = self.world.time_of_day in sleep_times
            if hasattr(self, 'pack'):
                self.update_pack()
            if hasattr(self, 'group'):
                self.update_group()
                
            # Применяем охотничье поведение если определено
            if hunting_behavior:
                self.hunting = (
                    not self.sleeping and 
                    self.hunger > hunting_behavior.get('min_hunger', 40)
                )

        def move(self):
            if self.sleeping or self.world is None:
                return

            possible_moves = [pos for pos in self.world.get_neighbors(self.x, self.y)
                            if self.world.grid[pos[1]][pos[0]] is None or 
                            (isinstance(self.world.grid[pos[1]][pos[0]], Plant) and 
                            random.random() < 0.3)]
            
            if possible_moves and random.random() < self.get_speed():
                nx, ny = random.choice(possible_moves)
                self.world.grid[self.y][self.x] = None
                self.x, self.y = nx, ny
                self.world.grid[ny][nx] = self
                self.energy -= 1
        
        def eat(self):
            if self.sleeping or self.hunger < 20 or self.world is None:
                return

            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if target is None:
                    continue
                    
                if any(isinstance(target, food_type) for food_type in self.get_food_types()):
                    nutrition = self.get_nutrition(target)
                    self.world.remove_entity(target)
                    self.hunger = max(0, self.hunger - nutrition)
                    self.energy += nutrition / 2
                    return
                
        def reproduce(self):
            if (self.energy < 80 or 
                self.hunger > 50 or 
                random.random() > 0.05 or 
                self.world is None):
                return

            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if (target is not None and 
                    isinstance(target, self.__class__) and 
                    target != self and 
                    target.energy > 70 and 
                    target.hunger < 50):
                    
                    for cx, cy in self.world.get_neighbors(self.x, self.y):
                        if self.world.grid[cy][cx] is None:
                            new_animal = self.__class__()
                            new_animal.energy = 60
                            if self.world.add_entity(new_animal, cx, cy):
                                self.energy -= 30
                                target.energy -= 30
                                return
        
        animal_class.get_food_types = get_food_types
        animal_class.modify_behavior = modify_behavior
        animal_class.move = move
        animal_class.eat = eat
        animal_class.reproduce = reproduce
        
        return animal_class

# %%
class Plant(metaclass=EcosystemMeta):
    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.growth_rate = 1  # Скорость роста
        self.active = False  # Активен ли рост
        self.health = 100    # Здоровье растения
    def __iter__(self):
        raise TypeError(f"'{self.__class__.__name__}' object is not iterable")
        
    def __repr__(self):
            return f"<{self.__class__.__name__} at ({self.x}, {self.y})>"
    
    def grow(self):
        if self.world is None:
            return

        self.active = self.can_grow_in_time(self.world.time_of_day)
        
        if not self.active:
            return

        self.health = min(100, self.health + 5)
        self.spread()

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

# %%
class Animal(metaclass=EcosystemMeta):
    def __iter__(self):
        raise TypeError(f"'{self.__name__}' object is not iterable")    

    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.energy = 100   # Уровень энергии
        self.hunger = 0     # Уровень голода
        self.sleeping = False  # Спящий режим
        self.age = 0        # Возраст (в шагах симуляции)

    def update_behavior(self):
        if self.world is None:
            return
        self.age += 1
        self.modify_behavior()  # Вызов специфичного поведения

    def get_speed(self) -> float:
        return max(0.1, 1.0 - (self.hunger / 200))

    def get_nutrition(self, food) -> int:
        if isinstance(food, Plant):
            return 30
        elif isinstance(food, Animal):
            return 50
        return 0

    def update_hunger(self):
        self.hunger += 2
        if self.hunger > 100:  # Голод снижает энергию
            self.energy -= 5    

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

# %%
class Lumiere(Plant):
    GROWTH_TIMES = [TimeOfDay.DAY]

class Obscurite(Plant):
    GROWTH_TIMES = [TimeOfDay.NIGHT]

class Demi(Plant):
    GROWTH_TIMES = [TimeOfDay.EVENING, TimeOfDay.MORNING]


class Pauvre(Animal):
    FOOD_TYPES = (Lumiere,)  # Питается Lumiere
    SLEEP_TIMES = [TimeOfDay.NIGHT]  # Спит ночью

    def __init__(self):
        super().__init__()
        self.aggression = 0    # Уровень агрессии
        self.group = set()     # Группа особей
        self.group_size = 1    # Размер группы

    def update_group(self):
        self.group = {self}
        for dx in range(-3, 4):
            for dy in range(-3, 4):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Pauvre)):
                    self.group.add(self.world.grid[ny][nx])
        
        self.group_size = len(self.group)
        
        if self.group_size > 5 and random.random() < 0.1:
            self.split_group()

    def split_group(self):
        avg_x = sum(m.x for m in self.group) / len(self.group)
        avg_y = sum(m.y for m in self.group) / len(self.group)
        
        subgroup1 = set()
        subgroup2 = set()
        
        for member in self.group:
            if member.x < avg_x or (member.x == avg_x and member.y < avg_y):
                subgroup1.add(member)
            else:
                subgroup2.add(member)
        
        for member in subgroup1:
            dx = -1 if random.random() < 0.5 else 0
            dy = -1 if dx == 0 else 0
            nx, ny = member.x + dx, member.y + dy
            if (0 <= nx < self.world.width and 
                0 <= ny < self.world.height and 
                self.world.grid[ny][nx] is None):
                self.world.grid[member.y][member.x] = None
                member.x, member.y = nx, ny
                self.world.grid[ny][nx] = member

    def get_nutrition(self, food) -> int:
        if isinstance(food, Lumiere):
            if self.world.time_of_day == TimeOfDay.MORNING:
                return 50
            elif self.world.time_of_day == TimeOfDay.EVENING:
                return 20
            return 30
        return 0

class Malheureux(Animal):
    FOOD_TYPES = (Demi, Obscurite, Pauvre)  # Питается разными видами
    SLEEP_TIMES = [TimeOfDay.DAY, TimeOfDay.NIGHT]  # Спит днем и ночью
    HUNTING_BEHAVIOR = {
        'min_hunger': 40,  # Начинает охоту при голоде > 40
        'speed_boost': 1.2  # Увеличение скорости при охоте
    }
    def __init__(self):
        super().__init__()
        self.pack = set()    # Стая
        self.hunting = False # Режим охоты

    def update_pack(self):
        self.pack = {self}
        for dx in range(-2, 3):
            for dy in range(-2, 3):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Malheureux)):
                    self.pack.add(self.world.grid[ny][nx])
        
        if len(self.pack) > 3:
            for member in self.pack:
                member.aggression = True


    def get_speed(self) -> float:
        base_speed = super().get_speed()
        if self.hunting:
            return base_speed * 1.2  # Быстрее при охоте
        return base_speed * 0.8      # Медленнее в обычном режиме

# %%
class TestEcosystemMeta(TestCase):
    def test_plant_registration(self):
        self.assertIn('Lumiere', EcosystemMeta._registry)
        self.assertIn('Obscurite', EcosystemMeta._registry)
        self.assertIn('Demi', EcosystemMeta._registry)
    
    def test_animal_registration(self):
        self.assertIn('Pauvre', EcosystemMeta._registry)
        self.assertIn('Malheureux', EcosystemMeta._registry)
    
    def test_plant_methods(self):
        lumiere = Lumiere()
        self.assertTrue(hasattr(lumiere, 'can_grow_in_time'))
        self.assertTrue(hasattr(lumiere, 'spread'))
        
        self.assertTrue(lumiere.can_grow_in_time(TimeOfDay.DAY))
        self.assertFalse(lumiere.can_grow_in_time(TimeOfDay.NIGHT))
    
    def test_animal_methods(self):
        pauvre = Pauvre()
        self.assertTrue(hasattr(pauvre, 'get_food_types'))
        self.assertTrue(hasattr(pauvre, 'modify_behavior'))
        self.assertTrue(hasattr(pauvre, 'move'))
        self.assertTrue(hasattr(pauvre, 'eat'))
        
        self.assertEqual(pauvre.get_food_types(), (Lumiere,))

def run_tests():
    loader = TestLoader()
    suite = loader.loadTestsFromTestCase(TestEcosystemMeta)
    
    runner = TextTestRunner(verbosity=2)
    result = runner.run(suite)
    return result

test_result = run_tests()
# Out:
# test_animal_methods (__main__.TestEcosystemMeta.test_animal_methods) ... ok
# test_animal_registration (__main__.TestEcosystemMeta.test_animal_registration) ... ok
# test_plant_methods (__main__.TestEcosystemMeta.test_plant_methods) ... ok
# test_plant_registration (__main__.TestEcosystemMeta.test_plant_registration) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.007s
#
# OK

# %%
def initialize_world(world: World, plant_density: float = 0.2, 
                    pauvre_count: int = 10, malheureux_count: int = 5):
    plant_classes = [Lumiere, Obscurite, Demi]  # Доступные типы растений
    
    num_plants = int(world.width * world.height * plant_density)
    
    for _ in range(num_plants):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                plant_class = random.choice(plant_classes)
                plant = plant_class()
                if world.add_entity(plant, x, y):
                    break
    
    for _ in range(pauvre_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                pauvre = Pauvre()
                if world.add_entity(pauvre, x, y):
                    break
    
    for _ in range(malheureux_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                malheureux = Malheureux()
                if world.add_entity(malheureux, x, y):
                    break

def run_simulation(width: int = 20, height: int = 20, 
                   plant_density: float = 0.2, 
                   pauvre_count: int = 10, malheureux_count: int = 5,
                   steps: int = 100, delay: float = 0.5):
    world = World(width, height)
    initialize_world(world, plant_density, pauvre_count, malheureux_count)
    
    try:
        for _ in range(steps):
            world.step()      # Шаг симуляции
            world.display()   # Отображение состояния
            time.sleep(delay) # Задержка для удобства наблюдения
    except KeyboardInterrupt:
        print("\nСимуляция остановлена пользователем.")
    except Exception as e:
        print(f"Ошибка: {e}")
    
    print("Симуляция завершена.")
    print(f"Итоговые показатели: День {world.day_counter}, Всего существ: {len(world.entities)}")
    print(f"Растений: {sum(1 for e in world.entities if isinstance(e, Plant))}")
    print(f"Травоядных: {sum(1 for e in world.entities if isinstance(e, Pauvre))}")
    print(f"Хищников: {sum(1 for e in world.entities if isinstance(e, Malheureux))}")

if __name__ == "__main__":
    run_simulation(
        width=20,            # Ширина мира
        height=20,           # Высота мира
        plant_density=0.2,   # Плотность растений (0.0 - 1.0)
        pauvre_count=15,     # Начальное количество травоядных
        malheureux_count=5,  # Начальное количество хищников
        steps=200,           # Количество шагов симуляции
        delay=0.3            # Задержка между шагами (сек)
    )
# Out:
# День: 0 Время: Утро (Шаг: 1)
# Существ: 133 (Растений: 113, Травоядных: 15, Хищников: 5)
# . . . . . . . . l . . D . D D D d . l .
# . D . . . P . . . . d o d d . l . . . .
# . . . . . . . . . . . D D d . . . . . .
# l . . . . . . . M . . d . d . . o o P .
# o . . D . . . o . . d . . . . . . o . .
# o D . . . . . D d . o D . o D . l o l .
# d d d . o P . l . . . . . . . . . o . .
# . D . D . . . . d . . . P . M . . o . .
# . d . d . . . . d D d . . . . . . . . M
# P l P . D . . . . . . . . o . . . l . .
# . d d d . d D d . . M . . . . . . . . .
# . l . . . o . . . . P . . . . . . l o .
# P . . P . . . l . o . P o . . . d . d .
# . . . o . . . l o . . . . . d D d D d .
# l . . . . . P . . P . . . . d o D . . D
# . . . . . . . . . d . . . o P . . l P .
# . . . l . . . . . d D . . . . . . . . D
# l . o o . . . . . . D . . . . . D . l .
# . D . . P . . . l . . D d . . . . . o .
# . . . o . . . . . o d D M . l . l D d .
#
# День: 0 Время: Утро (Шаг: 2)
# Существ: 173 (Растений: 153, Травоядных: 15, Хищников: 5)
# . . . . . . P . l d . D d D D D D . l .
# d D . . . . . . . . D d D D d l . . . .
# . d . . . . . M . . . D D D d . . . . P
# l . . . . . . . . d . D d D . . o o . .
# o . . D d . d o d . D . . . . d . o . .
# o D d d . . . D D d o D . o D . l o l .
# D D D . o . . l . . . . . d M . . o . .
# . D d D . P . . D d d . . . . . . o . .
# . D d D d . . . D D D d . P . . . . M .
# P l . P D . d . d . . . . o . . . l . .
# . D D D d D D D d P M . . . . . . . . .
# . l d . . o d d . . . . . . . . . l o .
# . P . . . . . l . o . . o . . d D . D .
# . . P o . . . l o . . . P d D D D D D .
# l . . . . . . . . . P . . . D o D d . D
# . . . . . . . P d D d . . o . d d l . .
# . . . l . . . . . D D . . . . P d . P D
# l . o o . . . . . . D . d . . . D . l .
# . D . . . P . . l . d D D M . . . . o d
# . . . o . . . . . o D D . . l . l D D .
#
# День: 0 Время: Утро (Шаг: 3)
# Существ: 211 (Растений: 191, Травоядных: 15, Хищников: 5)
# . . . . . . . . l D . D D D D D D . l .
# D D d . . . . P M . D D D D D d . . . .
# . D d . . . . . . . d D D D D d . . . .
# l . . . . . . . d D d D D D d . o o P .
# o . . D D . D o D . D d d d . D . o . .
# o D D D . . . D D D o D d o D d l o l .
# D D D d o . . l . d d . . D . . . o . .
# . D D D . . . d D D D d . M . . . o . .
# d D D D D . P . D D D D . . . . . . . .
# . l P . D d D d D d M d . o P . . l . M
# . P D D D D D D D P . . . . . . . . . .
# . l D . . o D D . . . . . . . d d l o d
# . . P . . . . l . o . . o . . D D d D .
# . . . o . . . l o P . . . D D D D D D .
# l . P . . . . . d d . P d d D d D D . D
# . . . . . . . . D D D . . o . D D l . .
# . . . l . . . d P D D d . . . . D . . D
# l . o o . . . . . . D . D . . P D P l .
# d D . . . . P . l d D D D M . . . d o D
# . . . o . . . . . o D D d . l . l D D .
#
# День: 0 Время: Утро (Шаг: 4)
# Существ: 257 (Растений: 237, Травоядных: 15, Хищников: 5)
# . . . . . . . P l D . D D D D D D . l .
# D D D . . . . . . M D D D D D D d . . .
# d D D . . . . d . d d D D D D D . . . P
# l d . . . . . . D D D D D D D d o o . .
# o . d D D . D o D d D D D D d D . o . .
# o D D D d . d D D D d D D o D D l o l .
# D D D D o . . l d D D . d D d d . o . .
# d D D D d d . D D D D D d . M . . o . .
# D D D D D . . d D D D D d . . P . . M .
# P l . d D P D D D D M D . o . . . l . .
# d . D P D D D D D . d . . . d d . d . .
# . l D P d o D D . d P . . . . D D l o D
# . . . . . d . l . o P . o . d D D D D d
# . P . o . . . l o . . . P D D D D D D .
# l . . . . . . . D D . . D D D D D D d D
# . . . . . . d d D P D d . o d D D l . .
# . . . l . . d D . D D D . . . . D . . D
# l . o o . . . . d . D d D d P . D . l .
# D D . . . . . . l D D D D . M . d D P D
# . . d o . . P . . d D D D d l . l D D .
#
# День: 0 Время: Утро (Шаг: 5)
# Существ: 305 (Растений: 285, Травоядных: 15, Хищников: 5)
# . d . d . . . . l D d D D D D D D . l .
# D D D d . . P . d . D D D D D D D d P .
# D D D . . . . D d M D D D D D D . . . .
# l D . d . . . d D D D D D D D D o o . .
# o d D D D d D d D D D D D D d D . o . .
# o D D D D . D D D D D D D d D D l o l .
# D D D D o . d l D D D d D D D D d o . .
# D D D D D D . D D D D D D d . d P o M .
# P D D D D d d D D D D D D M . . . . . .
# . d d D D . D D D D . D . o . . d l . .
# D . P . P D P D D P D M . . D D . D . .
# . l D . D o D D . D . . . . d D D d o D
# . d . d d D . l d o . P P . D D D D D D
# . . P o . d . l o . . d . D D D D D D d
# l . . . . . d d D D d d D D D D D D D D
# . . . . . . D D D P D D . o D D D d d .
# . . . l . d D D d D D D d . P d D d . D
# l . o o . . d . D d D d D D . d D d l d
# D D . . . . . . l D D D D d . d D D . D
# d . D o . . . P . D D D D D l M l P D d
#
# День: 0 Время: День (Шаг: 6)
# Существ: 317 (Растений: 297, Травоядных: 15, Хищников: 5)
# . d . d . . . . L d d d d d d d d . L l
# d d d d . P . . d . d d d d d d d d . P
# d d d . . . l d d m d d d d d d . . . .
# L d . d . . . d d d d d d d d d o o . .
# o d d d d d d d d d d d d d d d . o . l
# o d d d d . d d d d d d d d d d L o L .
# d d d d o . d L d d d d d d d d d o l .
# P d d d d d . d d d d d d d . d . o m .
# . d d d d d d d d d d d d m . . . P l .
# . P d d d P d d d d . d . o . . d L l .
# d . . . . d . d d . d m . . d d . d . .
# . L d . d P d d P d . . . . d d d d o d
# . d . d d d . L d o P . . . d d d d d d
# . l . o . d l L o . . P . d d d d d d d
# L . . P . . d d d P d d d d d d d d d d
# . l . l . . d d d . d d . o d d d d d .
# . l . L . d d d d d d d d . . d d d . d
# L . o o . . d . d d d d d d P d d d L d
# d d . . . . . . L d d d d d . d d d P d
# d . d o . . P . . d d d d d L m L . d d
#
# День: 0 Время: День (Шаг: 7)
# Существ: 333 (Растений: 312, Травоядных: 16, Хищников: 5)
# . d . d l l . l L d d d d d d d d . L L
# d d d d P . . l d . d d d d d d d d . .
# d d d . . l L d d m d d d d d d . . P .
# L d . d . l . d d d d d d d d d o o . .
# o d d d d d d d d d d d d d d d . o . L
# o d d d d . d d d d d d d d d d L o L .
# d d d d o . d L d d d d d d d d d o L .
# . d d d d d . d d d d d d d . d . o m .
# P d d d d d d d d d d d d m . . P . L .
# . . d d d . d d d d . d . o . . d L L l
# d P . . . d P d d P d m . . d d . d l l
# l L d . P . d d . d P . . . d d d d o d
# . d l d d d . L d o . . . . d d d d d d
# l L . o . d L L o P P . . d d d d d d d
# L . l . . . d d d . P d d d d d d d d d
# . L . P . . d d d . d d . o d d d d d .
# l L . L . d d d d d d d d . . P d d . d
# L l o o . . d . d d d d d d . d d d L d
# d d . . . P . . L d d d d d . d d d . d
# d . d o . . . . . d d d d d L m L P d d
#
# День: 0 Время: День (Шаг: 8)
# Существ: 344 (Растений: 323, Травоядных: 16, Хищников: 5)
# . d . d L L . L L d d d d d d d d . L L
# d d d d . l l L d . d d d d d d d d P .
# d d d . P L L d d m d d d d d d . . . .
# L d . d . L . d d d d d d d d d o o l .
# o d d d d d d d d d d d d d d d . o . L
# o d d d d . d d d d d d d d d d L o L .
# d d d d o . d L d d d d d d d d d o L .
# . d d d d d . d d d d d d d . d P o m l
# . d d d d d d d d d d d d m . . . . L .
# . P d d d . d d P d . d . o . . d L L L
# P . . . . d . d d . d m . . d d . d L L
# L L d . . . d P . d . . . . d d d d l d
# . d L d d P . L d P . P . . d d d d d d
# L L . o . d L L o . . . . d d d d d d d
# L l L . . . d d d . P d d d d d d d d d
# l L l P l . d d d P d d . o d d d d d .
# L L . L . d d d d d d d d . . . P d . d
# L L o o l . d . d d d d d d . d d d L d
# d d . . . . . l L d d d d d . l d P . d
# d . d o . . P . l d d d d d L m L . d d
#
# День: 0 Время: День (Шаг: 9)
# Существ: 362 (Растений: 341, Травоядных: 16, Хищников: 5)
# . d . d L L l L L d d d d d d d d l L L
# d d d d l L L L d . d d d d d d d d . l
# d d d . . L L d d m d d d d d d . l l P
# L d . d P L . d d d d d d d d d o o L l
# o d d d d d d d d d d d d d d d . o l L
# o d d d d . d d d d d d d d d d L o L l
# d d d d o . d L d d d d d d d d d o L .
# . d d d d d . d d d d d d d . d . o m L
# . d d d d d d d d d d d d m . . . P L .
# P . d d d . d d . d . d . o . . d L L L
# P l . . . d . d d P d m . . d d . d L L
# L L d l . P d . . d . . P . d d d d L d
# . l L d d . P L d . . . . . d d d d d d
# L L l o . d L L o P . P . d d d d d d d
# L L L . l l d d d . P d d d d d d d d d
# L L L . P . d d d . d d . o d d P d d .
# L L l L . d d d d d d d d . . . . d . d
# L L l o L . d l d d d d d d . d d d L d
# d d . . . P . L L d d d d d l L d . . d
# d . d o . . . . L d d d d d L m L P d d
#
# День: 0 Время: День (Шаг: 10)
# Существ: 372 (Растений: 351, Травоядных: 16, Хищников: 5)
# . d . d L L L L L d d d d d d d d L L L
# d d d d L L L L d . d d d d d d d d l L
# d d d P l L L d d m d d d d d d . L P .
# L d . d . L . d d d d d d d d d o o L L
# o d d d d d d d d d d d d d d d . o L L
# o d d d d . d d d d d d d d d d L l L L
# d d d d o . d L d d d d d d d d d l L .
# . d d d d d . d d d d d d d . d . l m L
# . d d d d d d d d d d d d m . . P . L l
# P P d d d . d d . d P d . o . . d L L L
# . L l . . d P d d . d m . . d d . d L L
# L L l L . . d . . d . . . . d d d d L d
# l L L d d l . L d . . . . P d d d d d d
# L L L o l P L L o . P . P d d d d d d d
# L L L . L L l d d . P d d d d d d d d d
# L L L . . P d d d . d d . o d d . d d .
# L L L L . d d d d d d d d . . P . d . d
# L L L o L . d L d d d d d d l d d d L d
# d d . . P . . L L d d d d d L L d . P d
# d . d o . . . l L d d d d d L m L . d d
#
# День: 0 Время: День (Шаг: 11)
# Существ: 373 (Растений: 352, Травоядных: 16, Хищников: 5)
# . d . d L L L L L d d d d d d d d . L L
# d d d d L L L L l . d d d d d d d P L L
# d d d . . L L l d m d d d d d d . L . l
# L d . P . L . d d d d d d d d d o o L L
# o d d d d d d d d d d d d d d d . l L L
# o d d d d . d d d d d d d d d d L L L L
# d d d d o . d L d d d d d d d d l L L .
# . d d d d d l d d d d d d d . d . L m L
# P d d d d d d d d d d d d m . P . . L L
# P . d d d . d d . d . d . o . . d L L L
# . L L l . d P d d P d m . . d d . l L L
# L L L L . . d . . d . . P . d d d d L d
# L L L d d L l L d . . . . . d d d d d d
# L L L o . P L L o P . P . d d d d d d d
# L L L . L L L d d . . d P d d d d d d d
# L L L l P . d d d . d d . o d d . d d .
# L L L L . d d d d d d d d . . . . d . d
# L L . o L . d L d d d d d d L d P d L d
# d d l P . . l L L d d d d l L . d P . d
# d . d o . . . L L d d d d d L m . . d d
#
# День: 0 Время: Вечер (Шаг: 12)
# Существ: 408 (Растений: 388, Травоядных: 15, Хищников: 5)
# d D . D l l l l l D D D D D D D D . l l
# D D D D l l l l l d D D D D d D D . l l
# D D D P d l l l . M d D D D D D P l . l
# l d d . d l d D D D D D D D D D o o l l
# o D D D D D D D D d D D D d D D d l l l
# o D D D D d D D D D D D D D D D l l l l
# D D D D d . D l D D D D D . D D l l l .
# d P D D D D l D d D D D D D M D . l M l
# . D D D D D D D D D D D D . P . . . l l
# . d D d D P D d d D P D d o d . D l l l
# P l l l d D . D D . D . . . D D . l l l
# l l l l . d d d d D M P . d D D D d l D
# l l l D D l l l D . P . . d D D D D D D
# l l l o d . l l d P d . P D D D D D D D
# l l l P l P l D D d d D . D D D D D D D
# l l l l . d D D D d D D d o D D . D D d
# l l l l . d D D D D D D D d d . d d d D
# l l d o l . D l d D D D D D l D . D l D
# D D l . . . l l l D D D D l l P D . P D
# D . D o P . . l l D D D D . M . d d D D
#
# День: 0 Время: Вечер (Шаг: 13)
# Существ: 431 (Растений: 411, Травоядных: 15, Хищников: 5)
# D D d D l l l l l D D D D D D D D . l l
# D D D P l l l l l D D D D D D D D . l l
# D D D . D l l l d M D D D D D D . P . l
# l D d . D l D D D D D D D D D D o o l l
# o D D D D D D D D d D D D D D D D l l l
# d D D D D D D D D D D D D D D D l l l l
# D D D D D d D d D D D D D d M D l l l .
# D P D D D D l D D D D D D D . D . l . l
# . D D D D D D D D D D D D d . P d M l l
# d d D D D . D d d D P D D o D . D l l l
# . P l d D P d D D d D M d . D D d l l l
# l l l l d D D D D D . . P D D D D D l D
# l l l D D l l d D . P . d D D D D D D D
# l l l o D P l l D . D P . D D D D D D D
# l l l . l . l D D D D D d P D D D D D D
# l l P l d D D D D D D D d d D D d D D D
# l l l l . D D D D D D D D D D . D D d D
# l l D o l d D l D D D D D D l P d D l D
# D D l d P . l l l D D D D l l M D P . D
# D . D o . . . l l D D D D d . d D D D D
#
# День: 0 Время: Вечер (Шаг: 14)
# Существ: 450 (Растений: 430, Травоядных: 15, Хищников: 5)
# D D P D l l l l l D D D D D D D D d l l
# D D D . l l l l l D D D D D D D D d P l
# D D D d D l l l D . D D D D D D . . . l
# l D D d D l D D D D M D D D D D o o l l
# d D D D D D D D D D D D D D D D D l l l
# D D D D D D D D D D D D D D D D l l l l
# D D D D D D D d D D D D D D . D l l l .
# D P D D D D d D D D D D D M d P d l M l
# d D D D D D D D D D D D D D . . D . l l
# D d D D D d D D d D P D D o D . D l l l
# . . P d P . D D D D D . D P D D D l l l
# l l l d d D D D D P M d . D D D D D l D
# l l l D P l l D D . P d D D D D D D D D
# l l l d D . l d D d D . d D D D D D D D
# l l l d l . l D D D D D D . D D D D D D
# l l . P D D D D D D D D P d D D D D D D
# l l l l d D D D D D D D D D D d D D D D
# l l D o l D D l D D D D D D l . d D d D
# D D l D . d l l l D D D D d l P D . d D
# D . D o d P . l l D D D D D M D D P D D
#
# День: 0 Время: Вечер (Шаг: 15)
# Существ: 468 (Растений: 447, Травоядных: 16, Хищников: 5)
# D P . D l l l l l D D D D D D D D D l l
# D D D d l l l l l D D D D D D D D D . l
# D D D D D l l l D d D D D D D D d . P l
# d D D D D l D D D D M D D D D D o o l l
# D D D D D D D D D D D D D D D D D l l l
# D D D D D D D D D D D D D D D D l l l l
# D D P D D D D D D D D D D D . D P l l .
# D . D D D D D D D D D D D . D . D l M l
# d D D D D D D D D D D D M D . . D d l l
# D d D D D D D D D D P D D o D d D l l l
# . d P D P d D D D M D d D P D D D d l l
# l l d P d P D D D . . D d D D D D D l D
# l l l D . l d D D P . D D D D D D D D D
# l l l D D . l D D P D d d D D D D D D D
# l l l D P d d D D D D D D d D D D D D D
# l l d . D D D D D D D D . d D D D D D D
# l l l l D D D D D D D P D D D D D D D D
# l l D d l D D l D D D D D D d d D D D D
# D D d D d D l l d D D D D D l . D d D D
# D d D o D . P l l D D D D D P M D P D D
#
# День: 0 Время: Вечер (Шаг: 16)
# Существ: 483 (Растений: 462, Травоядных: 16, Хищников: 5)
# P . d D l l l l l D D D D D D D D D l l
# D D D D d l l l d D D D D D D D D D d P
# D D D D D l d d D D D D D D D D D d . l
# D D D D D d D D D D M D D D D D d o l l
# D D D D D D D D D D D D D D D D D l l l
# D D D D D D D D D D D D D D D D l l l l
# D D . D D D D D D D D D D D d D . l l M
# D P D D D D D D D D D D M d D P D l . l
# D D D D D D D D D D D D . D d d D D l l
# D d D P P D D D D D P D D P D D D l l l
# d D . D . d D D D M D d D . D D D D l l
# l d d P d . D D D P d D D D D D D D d D
# l l d D d d P D D P d D D D D D D D D D
# l l l D D d l D D . D d d D D D D D D D
# l l l D P D d D D D D D D d D D D D D D
# l l D d D D D D D D D D d d D D D D D D
# l l l l D D D D D D D P D D D D D D D D
# d l D D d D D d D D D D D D D D D D D D
# D D D D D D l l D D D D D P d d D D D D
# D D D o D P . l l D D D D D . M D . P D
#
# День: 0 Время: Вечер (Шаг: 17)
# Существ: 493 (Растений: 472, Травоядных: 16, Хищников: 5)
# P . D D d l l l d D D D D D D D D D l l
# D D D D D d l l D D D D D D D D D D P .
# D D D D D l D D D M D D D D D D D D d l
# D D D D D D D D D D . D D D D D D o l l
# D D D D D D D D D D D D D D D D D l l l
# D D D D D D D D D D D D D D D D l l l M
# D D d D D D D D D D D D D D D D . l l .
# D . P D D D D D D D D D . D D . P d . l
# D D D D D P D D D D D D d M d D D D l l
# D D D . P D D D D D P D D . D D D l l l
# d D d D d D D D D M D D D P D D D D d l
# d D D . d d D D D P D D D D D D D D D D
# l l D P d d . P P . D D D D D D D D D D
# l l d D D D d D D d D D D D D D D D D D
# l l l D . D D D D D D D D d D D D D D D
# l l D D P D D D D D D D d d D D D D D D
# l l l d D D D D D D D . D D D D D D D D
# D d D D D D D D D D P D D D D D D D D D
# D D D D D D P d D D D D D . P D D D D D
# D D D o D . . l l D D D D D d . M d P D
#
# День: 0 Время: Ночь (Шаг: 18)
# Существ: 493 (Растений: 472, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d l l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d . p d d d d d P d d . d d d l l l
# d d d d d d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d . p p . d d d d d d d d d d
# l l d d d d d d d d d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d d d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 0 Время: Ночь (Шаг: 19)
# Существ: 493 (Растений: 472, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d l l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d . p d d d d d P d d . d d d l l l
# d d d d d d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d . p p . d d d d d d d d d d
# l l d d d d d d d d d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d d d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 0 Время: Ночь (Шаг: 20)
# Существ: 493 (Растений: 472, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d l l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d . p d d d d d P d d . d d d l l l
# d d d d d d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d . p p . d d d d d d d d d d
# l l d d d d d d d d d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d d d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 0 Время: Ночь (Шаг: 21)
# Существ: 493 (Растений: 472, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d l l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d . p d d d d d P d d . d d d l l l
# d d d d d d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d . p p . d d d d d d d d d d
# l l d d d d d d d d d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d d d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 0 Время: Ночь (Шаг: 22)
# Существ: 494 (Растений: 473, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d l l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d . p d d d d d P d d . d d d l l l
# d d d d o d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d o p p . d d d d d d d d d d
# l l d d d d d d d o d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d o d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 0 Время: Ночь (Шаг: 23)
# Существ: 495 (Растений: 474, Травоядных: 16, Хищников: 5)
# p . d d d l l l d d d d d d d d d d l l
# d d d d d d l l d d d d d d d d d d p .
# d d d d d l d d d m d d d d d d d d d l
# d d d d d d d d d d . d d d d d d O l l
# d d d d d d d d d d d d d d d d d o l l
# d d d d d d d d d d d d d d d d l l l m
# d d d d d d d d d d d d d d d d . l l .
# d . p d d d d d d d d d . d d . p d . l
# d d d d d p d d d d d d d m d d d d l l
# d d d o p d d d d d P d d . d d d l l l
# d d d d O d d d d m d d d p d d d d d l
# d d d . d d d d d p d d d d d d d d d d
# l l d p d d O p p . d d d d d d d d d d
# l l d d d d d d d O d d d d d d d d d d
# l l l d . d d d d d d d d d d d d d d d
# l l d d p d d d d d d d d d d d d d d d
# l l l d d d d d d d d . d d d d d d d d
# d d d d d d d d d d p d d d d d d d O d
# d d d d d d p d d d d d d . p d d d d d
# d d d O d . . l l d d d d d d . m d p d
#
# День: 1 Время: Утро (Шаг: 24)
# Существ: 499 (Растений: 478, Травоядных: 16, Хищников: 5)
# . P D D D l l l . D D D D D D D D D . l
# D D D D d D l d d M D D D D D D D D P d
# D D D d D d D D D . d D D D D D d d D l
# D D d d D d D D D D d D D D D D D o l l
# D D D D D D D D D d D D D D D D D o l l
# D D D D D D D D D D D D D D D D d l l .
# D D D D D D D D D D D D D D D D . . l M
# D . P D D D D D D D D D . d D d . P . l
# D D D P D . D D . D D D D M d D D D l l
# D d D d P d D d d M P D D P D D D l l l
# D D d d o d d D D . D D D . D D D D D l
# D D D d d D d d D . D d D D D D D D D D
# l d D . P D o P . d P d d D d D D D D D
# l l D D D D d D D P d d d D D D D D D D
# l l d D P d D D D D D D d D D d D D D D
# l l D D . D D D D d D D D d D D D D D D
# l l d D D D D D D D D d D D D d D D D D
# D D D D D D D D D P . D D D D D D D o D
# D D d D D D . P D D D D D d . P D d d P
# D D D o D . . . l D D D D D D d M d . D
#
# День: 1 Время: Утро (Шаг: 25)
# Существ: 516 (Растений: 495, Травоядных: 16, Хищников: 5)
# P . D D D l l l M D D D D D D D D P . l
# D D D D d D l D D . D D D D D D D D . D
# D D D D D d D D D d D D D D D D D D D l
# D D D D D d D D D D D D D D D D D d l l
# D D D D D D D D D d D D D D D D D o l l
# D D D D D D D D D D D D D D D D D l l .
# D D D D D D D D D D D D D D D D d P l M
# D d . D D D D D D D D D M d D d d . . l
# D D P . D P D D M D D D D . D D D D l l
# D D D d P D D d D . P D D . D D D d l l
# D D d d d d D D D d D D P d D D D D D l
# D D D D d D d D D d D D D D D D D D D D
# d D D d P D o P d D P d d D D D D D D D
# l d D D D D d D D P D D D D D D D D D D
# l l D D . P D D D D D D d D D D D D D D
# l l D D d D D D D D D D D D D D D D D D
# l l D D D D D D D D D D D D D d D D D D
# D D D D D D D D D P d D D D D D D D d D
# D D D D D D P . D D D D D D d P M d D .
# D D D o D . d d l D D D D D D D . d d P
#
# День: 1 Время: Утро (Шаг: 26)
# Существ: 529 (Растений: 508, Травоядных: 16, Хищников: 5)
# . d D D D l l l M D D D D D D D D . d l
# P D D D D D l D D d D D D D D D P D . D
# D D D D D D D D D D D D D D D D D D D l
# D D D D D D D D D D D D D D D D D D l l
# D D D D D D D D D D D D D D D D D o l l
# D D D D D D D D D D D D D D D D D l l .
# D D D D D D D D D D D D D D D D D . l M
# D d d D D D P D D D D D . d D D P d . l
# D D P d P . D D M D D M D d D D D D l l
# D D D D . D D D D d P D D d D D D D l l
# D D D d d d D D D D D D . D D D D D D l
# D D D D d D d P D d D D D P D D D D D D
# D D D d . D o . d P P d D D D D D D D D
# l D D D P D d D D . D D D D D D D D D D
# l d D D d . D D D D D D d D D D D D D D
# l l D D d D P D D D D D D D D D D D D D
# l l D D D D D D D D P D D D D d D D D D
# D D D D D D D D D . D D D D D D D D D D
# D D D D D D . P D D D D D D d M . D D P
# D D D d D d D D d D D D D D D D P D D .
#
# День: 1 Время: Утро (Шаг: 27)
# Существ: 545 (Растений: 524, Травоядных: 16, Хищников: 5)
# d P D D D d l l . D D D D D D P D d D l
# . D D D D D d D M d D D D D D D . D d D
# D D D D D D D D D D D D D D D D D D D d
# D D D D D D D D D D D D D D D D D D l l
# D D D D D D D D D D D D D D D D D d l l
# D D D D D D D D D D D D D D D D D d l M
# D D D D D D D P D D D D D D D D D d l .
# D D d D D D . D D D D M d d D D . D d l
# D D P D P d D D . D D . D d D P D D d l
# D D D D d D D D M d P D D D D D D D l l
# D D D d d d P D D D D D d D D D D D D l
# D D D D d D D . P D D P D P D D D D D D
# D D D D d D d d d . . d D D D D D D D D
# l D D D . P D D D d D D D D D D D D D D
# l D D D D P D D D D D D D D D D D D D D
# l l D D D D . D D D D D D D D D D D D D
# l d D D D D D D D D P D D D D D D D D D
# D D D D D D D D D d D D D D D D D D D D
# D D D D D D d . D D D D D D d . M D D .
# D D D D D D D P D D D D D D D D P D D P
#
# День: 1 Время: Утро (Шаг: 28)
# Существ: 559 (Растений: 538, Травоядных: 16, Хищников: 5)
# P . D D D D l l d D D D D D D P D D D l
# d D D D D D D D M d D D D D D D d D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D l l
# D D D D D D D D D D D D D D D D D D d l
# D D D D D D D D D D D D D D D D D D l M
# D D D D D D D . P D M D D D D D D D l .
# D P d D D D d D D D D . D d D P d D D l
# D D . P . D D D d D D d D d D . D D D l
# D D D D D D D D . M P D D D D D D D l l
# D D D d d d . P D D D D d D D D D D D l
# D D D D d D D d P D D . D . D D D D D D
# D D D D d D D D d d P D D P D D D D D D
# l D D D P P D D D d D D D D D D D D D D
# l D D D D . D D D D D D D D D D D D D D
# l l D D D D d D D D D D D D D D D D D D
# l D D D D D D D D D P D D D D D D D D D
# D D D D D D D D D d D D D D D D D D D D
# D D D D D D d d D D D D D D d d . P D P
# D D D D D D P . D D D D D D D D M D D .
#
# День: 1 Время: Утро (Шаг: 29)
# Существ: 573 (Растений: 552, Травоядных: 16, Хищников: 5)
# P d D D D D l d D D D D D D D . P D D l
# D D D D D D D D M d D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D D D D D D D D D d l
# D D D D D D D D D D D D D D D D D D D l
# D D D D D D D P D D D M D D D D D D l M
# P D D D D D D d . D . D D D D D D D l d
# D . d D D D d D D D D d D D P . D D D l
# D D d . d D D D d D D d D d D d D D D l
# D D D P D D D D M . P D D D D D D D d d
# D D D d d d d P D D D D D D D D D D D d
# D D D D d D D d . D D d P . D D D D D D
# D D D D d D D D P P . D D . D D D D D D
# l D D D . P D D D D D D D D D D D D D D
# l D D P D d D D D D D D D D D D D D D D
# l d D D D D d D D D D P D D D D D D D D
# l D D D D D D D D D . D D D D D D D D D
# D D D D D D D D D D D D D D D D D D P D
# D D D D D D d D D D D D D D D d M . D .
# D D D D D D . P D D D D D D D D . D P d
#
# День: 1 Время: День (Шаг: 30)
# Существ: 575 (Растений: 554, Травоядных: 16, Хищников: 5)
# P d d d d d L d d d d d d d d P . d d L
# d d d d d d d d m d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d L
# d d d d d d d d d d d d d d d d d d d L
# d d d d d d d P d d d m d d d d d d L m
# . d d d d d d d . d . d d d d d d d L d
# d P d d d d d d d d d d d d . l d d d L
# d d d . P d d d d d d d d d P d d d d L
# d d d . d d d d m . P d d d d d d d d d
# d d d d d d d . d d d d d d d d d d d d
# d d d d d d d d P d d d . . d d d d d d
# d d d d d d d d P . P d P . d d d d d d
# L d d P . . d d d d d d d d d d d d d d
# L d d . P d d d d d d d d d d d d d d d
# L d d d d d d d d d d P d d d d d d d d
# L d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d d d P d
# d d d d d d d d d d d d d d d d m . d .
# d d d d d d P . d d d d d d d d . d P d
#
# День: 1 Время: День (Шаг: 31)
# Существ: 576 (Растений: 555, Травоядных: 16, Хищников: 5)
# P d d d d d L d d d d d d d d . P d l L
# d d d d d d d d m d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d L
# d d d d d d P d d d d d d d d d d d d L
# d d d d d d d . d d d m d d d d d d L m
# . d d d d d d d . d . d d d d d d d L d
# d . d d d d d d d d d d d d . P d d d L
# d d P . P d d d d d d d d d . d d d d L
# d d d . d d d d m . P d d d d d d d d d
# d d d d d d d . d d d d d d d d d d d d
# d d d d d d d d P P d P . . d d d d d d
# d d d d d d d d . P . d . . d d d d d d
# L d P . . . d d d d d d d d d d d d d d
# L d d . P . d d d d d d d d d d d d d d
# L d d d d d d d d d d . d d d d d d d d
# L d d d d d d d d d . d P d d d d d d d
# d d d d d d d d d d d d d d d d d d . d
# d d d d d d d P d d d d d d d d m P d .
# d d d d d d . l d d d d d d d d . P . d
#
# День: 1 Время: День (Шаг: 32)
# Существ: 575 (Растений: 554, Травоядных: 16, Хищников: 5)
# . d d d d d L d d d d d d d d . . P L L
# d P d d d d d d m d d d d d d d l d l d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d L
# d d d d d P . d d d d d d d d d d d d L
# d d d d d d d . d d d m d d d d d d L m
# . d d d d d d d . d . d d d l d d d L d
# d . d d d d d d d d d d d d . . d d d L
# d d P P . d d d d d d d d d P d d d d L
# d d d . d d d d m . P d d d d d d d d d
# d d d d d d d . d d d d d d d d d d d d
# d d d d d d d P . P d . . . d d d d d d
# d d d d d d d d . P . d P . d d d d d d
# L d P . . . d d d d d d d d d d d d d d
# L d d . . P d d d d d d d d d d d d d d
# L l d d . d d d d d d . d d d d d d d d
# L d d d d d d d d d . d . d d d d d d d
# d d d d d d d d d d d P d d d d d d . d
# d d d d d d d P d d d d d d d d m . d .
# d d d d d d . L d d d d d d d d P P . d
#
# День: 1 Время: День (Шаг: 33)
# Существ: 580 (Растений: 559, Травоядных: 16, Хищников: 5)
# P d d d d d L d d d d d d d d . P . L L
# d . d d d d d d m d d d d d d d L l L d
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d d d d d d d d d d d d d d L
# d d d d d . P d d d d d d d d d d d l L
# d d d d d d d . d d d m d d d d d d L m
# . d d d d d d d . d . d d d L l d l L d
# d P d d d d d d d d d d d d l P d d d L
# d d P . . d d d d d d d d d . d d d d L
# d d d . d d d d m . P d d d d d d d d d
# d d d d d d d P d d d d d d d d d d d d
# d d l d d d d . . P d . . . d d d d d d
# d P d d d d d d . . P d . . d d d d d d
# L d . . P l d d d d d P d d d d d d d d
# L d d l . . l d d d d d d d d d d d d d
# L L d d l d d d d d d . d d d d d d d d
# L d d d d d d d d d . d . d d d d d d d
# d d d d d d d d d d d . d d d d d d . d
# d d d d d d P . d d P d d d d d m . d .
# d d d d d d l L d d d d d d d P P . . d
#
# День: 1 Время: День (Шаг: 34)
# Существ: 580 (Растений: 559, Травоядных: 16, Хищников: 5)
# . d d d d d L d d d d d d d d . . . L L
# d P d d d d d d m d d d d d d d P L L l
# d d d d d d d d d d d d d d d d d l l L
# d d d d d d d P d d d d d d d d d d l L
# d d d d d . . d d d d d d d d d d l L L
# d d d d d d d . d d d m d d d d d d L m
# P d d d d d d d . d . d d d L . l L L d
# d . P d d d d d d d d d d d L . P d d L
# d d . . . d d d d d d d d d . d d d d L
# d d d . d d d d m . P d d d d d d d d d
# d d d d d d d . d d d d d d d d d d d d
# d d L d d d l . P P d . . . d d d d d d
# d . d d d P d d . . . P . . d d d d d d
# L l P l . L d d d d d P d d d d d d d d
# L l d L . . L d d d d d d d d d d d d d
# L L d l L d d d d d d . d d d d d d d d
# L d d l l d d d d d . d . d d d d d d d
# d d d d d d P d d d d . d d d d d d . d
# d d d d d d . . d d P d d d d d m . d .
# d d d d d d L L d d d d d d d P P . . d
#
# День: 1 Время: День (Шаг: 35)
# Существ: 587 (Растений: 566, Травоядных: 16, Хищников: 5)
# . d d d d d L d d d d d d d d . P l L L
# d P d d d d d d m d d d d d d d . L L l
# d d d d d d d d d d d d d d d d l L l L
# d d d d d d d . d d d d d d d d d l L L
# d d d d d . P d d d d d d d d d d L L L
# d P d d d d d . d d d m d d d d d d L m
# . d d d d d d d . d . d d d L l L L L d
# d . . d d d d d d d d d d d L l . d d L
# d d P . . d d d d d d d d d . d P d d L
# d d d . d d d d m . P d d d d d d d d d
# d d l d d d d . d d d d d d d d d d d d
# l d L d d d L . . P d . . . d d d d d d
# d . P l d . d d P . P . . . d d d d d d
# L L . L l P l d d d d P d d d d d d d d
# L L l L l l L d d d d d d d d d d d d d
# L L l L L d d d d d d . d d d d d d d d
# L d l L L d d d d d . d . d d d d d d d
# d d d d d d . d d d d . d d d d d d . d
# d d d d d P l l d P . d d d d d m . d .
# d d d d d . L L . d d d d d d P . P . d
#
# День: 1 Время: Вечер (Шаг: 36)
# Существ: 620 (Растений: 599, Травоядных: 16, Хищников: 5)
# d d D D D d l . D D D D D D D d . l l l
# d . D D D D D D M d D D D D D d P l l l
# D P D D D D D D D d d D D D D D l l l l
# D D D D D D D d D D d D D D D D d l l l
# D D D D D d . P D D D D D d D D D l l l
# P . D D D D D d D D . . D D D D D D l .
# d D D D D D D D d D d M D D l d l l l M
# D d d P D D D D D D D d d d l l d D . l
# D D . d d d D . D D D D D d d D . D D l
# D D d d d d D D M d P D D d D D D P D D
# D D l d d d d d D d D D D D D D D d D D
# l D . D d d l d P . D d d d D D D D D D
# D d . P d d d d P d P d d d D D D D D D
# l l d l l . P d d d P . D D D D D D D D
# l l l l l . l D D D D D d D D D D D D D
# l l l l l D d D D d D d D d D D d D D D
# l D l l l D D D D D d D d D D d d D D D
# D d D D D D P D D D P d D D d . D D d D
# D D d D D . l l D . . D D D D d M d D d
# D D D D D d l l d D D D D D P . P . d D
#
# День: 1 Время: Вечер (Шаг: 37)
# Существ: 640 (Растений: 619, Травоядных: 16, Хищников: 5)
# D D D D D D l d D D D D D D D D P d l l
# P d D D D D D D M D D D D D D D . l l l
# D . D D D D D D D D d D D D D D l l l l
# D D D D D D D D D D d D D D D D D l l l
# D D D D D d d P D D D D D D D D D l l l
# . P D D D D D d D D d d D D D D D D l .
# D D D D D D D D d D D M D D l d d l l .
# D d P . D D D D D D D D d d l d d D M l
# D D d d D D D d D D D D D d D D d D D l
# D D d d d D D D M d P D D d D D D . P D
# D D d d d d D d D d D D D D D D D D D D
# l D d D d D d d P d D d d D D D D D D D
# D D d . d D d P . d P d d d D D D D D D
# l l P l d P . D d d . P D D D D D D D D
# l l l l d d l D D D D D d D D D D D D D
# l l l l d D D D D d D D D D D D D D D D
# l D l d l D P D D D P D D D D D D D D D
# D D D D D D . D D D . D D D D d D D D D
# D D D D D d l d D . d D D D D P M D D d
# D D D D D D l l D D D D D D . P . d D D
#
# День: 1 Время: Вечер (Шаг: 38)
# Существ: 654 (Растений: 633, Травоядных: 16, Хищников: 5)
# D D D D D D d D D D D D D D D D . D l l
# . P D D D D D M . D D D D D D D P d l l
# D d D D D D D D D D d D D D D D d d l l
# D D D D D D D D D D D D D D D D D l l l
# D D D D D D d P D D D D D D D D D d l l
# d . P D D D D D D D d D D D D D D D l .
# D D P D D D D D D D D M D D d D D d l .
# D D . d D D D D D D D D D D d d D D . l
# D D d d D D D d D D D D D d D D d D D M
# D D D d d D D D . D P D D D D D D d . D
# D D d d d d D d M d D D D D D D D D P D
# d D d D d D d P . d D d d D D D D D D D
# D D d d D P d P d d P P d D D D D D D D
# l l P d d . d D D d d . D D D D D D D D
# l l l d d d l D D D D D d D D D D D D D
# l l l l D D D P D D D D D D D D D D D D
# l D l D l D . D D D . D D D D D D D D D
# D D D D D D d D D P d D D D D d D D D D
# D D D D D d l D D d d D D D D M P D D D
# D D D D D D l d D D D D D D d . P d D D
#
# День: 1 Время: Вечер (Шаг: 39)
# Существ: 666 (Растений: 645, Травоядных: 16, Хищников: 5)
# D D D D D D D D M D D D D D D D d D l l
# . P D D D D D . d D D D D D D P . D d l
# D D D D D D D D D D d D D D D D D D d l
# D D D D D D D D D D D D D D D D D l l l
# D D D D D D P . D D D D D D D D D D l l
# d . P D D D D D D D d D D D D D D D l .
# D D P D D D D D D D D . M D d D D D d .
# D D d d D D D D D D D D D D d d D D d l
# D D D d D D D D D D D D D d D D d D D M
# D D D d d D D D d D P D D D D D D D d D
# D D d d d d D d M d D D D D D D D P . D
# D D d D d D d P d d D d d D D D D D D D
# D D P d D . P . D d P P d D D D D D D D
# l l . D d P D D D d d d D D D D D D D D
# l l d d d d d P D D D D d D D D D D D D
# l l l l D D D . D D D D D D D D D D D D
# l D d D d D d D D D P D D D D D D D D D
# D D D D D D d D D . d D D D D d D D D D
# D D D D D D d D D d d D D D D P M D D D
# D D D D D D d D D D D D D D d P . d D D
#
# День: 1 Время: Вечер (Шаг: 40)
# Существ: 679 (Растений: 658, Травоядных: 16, Хищников: 5)
# D D D D D D D D M D D D D D D D P D d l
# d . D D D D D d D D D D D D D . d D D l
# D P D D D D D D D D D D D D D D D D D l
# D D D D D D D D D D D D D D D D D d l l
# D D D D D D P d D D D D D D D D D D l l
# D d P D D D D D D D d D D D D D D D d .
# D D P D D D D D D D D d M D D D D D D d
# D D d d D D D D D D D D D D d D D D D l
# D D D d D D D D D D D D D d D D d D D M
# D D D d d D D D d D P D D D D D P D D D
# D D D d d d P d . M D D D D D D D . d D
# D P D D d D d . d d D d d D D D D D D D
# D D . d D d P d D d P . d D D D D D D D
# l d d D d . P D P D d d P D D D D D D D
# l d D d d d d . D D D D d D D D D D D D
# d l d d D D D d D D D D D D D D D D D D
# l D D D D D d D D D . D D D D D D D D D
# D D D D D D d D D . P D D D D d D D D D
# D D D D D D d D D d d D D D D . M D D D
# D D D D D D d D D D D D D D P P d d D D
#
# День: 1 Время: Вечер (Шаг: 41)
# Существ: 692 (Растений: 671, Травоядных: 16, Хищников: 5)
# D D D D D D D M . D D D D D D P . D D l
# d d D D D D D d D D D D D D D d d D D l
# D P D D D D D D D D D D D D D D D D D l
# D D D D D D D D D D D D D D D D D D l l
# D D D D D D P d D D D D D D D D D D l l
# D d . D D D D D D D D D D D D D D D D d
# D P P D D D D D D D D d . D D D D D D D
# D D d d D D D D D D D D M D D D D D D d
# D D D d D D D D D D D D D D D P d D D .
# D D D d D D P D D D P D D D D D . D D M
# D D D d d D . D d . D D D D D D D d d D
# D . D D d D d d M d D D d D D D D D D D
# P D d d D d . d D d P d d D D D D D D D
# d d d D d P . D . D d D P D D D D D D D
# l D D D d P d d P D D D d D D D D D D D
# D l D d D D D D D D D D D D D D D D D D
# d D D D D D D D D D d P D D D D D D D D
# D D D D D D D D D d . D D D D d D D D D
# D D D D D D d D D D d D D D D d M D D D
# D D D D D D d D D D D D D D P P d d D D
#
# День: 1 Время: Ночь (Шаг: 42)
# Существ: 693 (Растений: 672, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d d d . d d . d d d d d d d d d d
# d . d d d d d d m d d d d d d d d d d d
# p d d d d d o d d d p d d d d d d d d d
# d d d d d p . d . d d d p d d d d d d d
# l d d d d p d d p d d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m d d d
# d d d d d d d d d d d d d d p p d d d d
#
# День: 1 Время: Ночь (Шаг: 43)
# Существ: 695 (Растений: 674, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d d d o d d . d d d d d d d d d d
# d . d d d d d d m d d d d d d d d d d d
# p d d d d d O o d d p d d d d d d d d d
# d d d d d p . d o d d d p d d d d d d d
# l d d d d p d d p d d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m d d d
# d d d d d d d d d d d d d d p p d d d d
#
# День: 1 Время: Ночь (Шаг: 44)
# Существ: 695 (Растений: 674, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d d d O d d . d d d d d d d d d d
# d . d d d o d d m d d d d d d d d d d d
# p d d d d d O O d d p d d d d d d d d d
# d d d d d p . d O d d d p d d d d d d d
# l d d d d p d d p d d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m d d d
# d d d d d d d d d d d d d d p p d d d d
#
# День: 1 Время: Ночь (Шаг: 45)
# Существ: 695 (Растений: 674, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d o d O d d . d d d d d d d d d d
# d . d d d O o o m d d d d d d d d d d d
# p d d d o o O O d d p d d d d d d d d d
# d d d d d p . o O o d d p d d d d d d d
# l d d d d p d d p d d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m d d d
# d d d d d d d d d d d d d d p p d o d d
#
# День: 1 Время: Ночь (Шаг: 46)
# Существ: 696 (Растений: 675, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d O o O o d . d d d d d d d d d d
# d . d d o O O O m d o d d d d d d d d d
# p d d d O O O O d o p d d d d d d d d d
# d d d d d p o O O O d d p d d d d d d d
# l d d d d p d d p o d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m o d d
# d d d d d d d d d d d d d d p p d O d d
#
# День: 1 Время: Ночь (Шаг: 47)
# Существ: 696 (Растений: 675, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d p . d d l
# d d d d d d d d d d d d d d d d d d d l
# d p d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d l l
# d d d d d d p d d d d d d d d d d d l l
# d d . d d d d d d d d d d d d d d d d d
# d p p d d d d d d d d d . d d d d d d d
# d d d d d d d d d d d d m d d d d d d d
# d d d d d d d d d d d d d d d p d d d .
# d d d d d d p d d d P d d d d d . d d m
# d d d d O O O O d . d d d d d d d d d d
# d . d d o O O O m o O o d d d d d d d d
# p d d d O O O O d O p d d d d d d d d d
# d d d d d p O O O O o d p d d d d d d d
# l d d d d p d d p O d d d d d d d d d d
# d l d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d d d d d d d d d m O o d
# d d d d d d d d d d d d d d p p d O o d
#
# День: 2 Время: Утро (Шаг: 48)
# Существ: 699 (Растений: 678, Травоядных: 16, Хищников: 5)
# d D D D D . M . d D D D D D D . P D D l
# d d D D d D D d d D D D D D d d D D D l
# D P D D D D D D D D d D D D D D d D D l
# D D D D D D P D D D D D D D D D D d l l
# D D D D D d . D D D D D D D D D D D l l
# D d P D D D D d D D D D D D D D D D d D
# D P . D D d D D D D D d d d d d d d d D
# D d D D d D d D D D D . . d d d d D d D
# D D d d d D D d d D D d M D d . d D D d
# D d d d d d . d D d P D D d D D P . d .
# D D d d o o o P d d D D d D D D D D M D
# d P d d o o o o M d o o d D D D D D D D
# . D d d o P o o d o P P d d D D D d D D
# D D d d d . P o o o d d . D D D D D D D
# l D D D d . d d . o d D d d D d D D D D
# D d D D D D D d D P D D D d D d D d D D
# D D D D D D d D D D P . d D D D d D D D
# D D D D D D D D D d d D D D D . d d d D
# D D d D D d d d D d d D D D d d M o d d
# D D D D D D d d D D D D D D P P d o o D
#
# День: 2 Время: Утро (Шаг: 49)
# Существ: 716 (Растений: 695, Травоядных: 16, Хищников: 5)
# D D D D D d . d D D D D D D D . P D D d
# d d D D D D D M d D D D D D d d D D D l
# D . D D D P D D D D d D D D D D d D D l
# D P D D D D . D D D D D D D D D D D l l
# D D P D D D d D D D D D D D D D D D d l
# D D . D D D D D D D D D D D D D D D D D
# P . d D D D D D D D D d d D D D d D D D
# D d D D d D D D D D D d d D D D D D d D
# D D d d d D D d d D D d . D D d d D D D
# D d D d d d P d D d P M D d D P . d D d
# D D P d o d o . d d D D d D D D D D M D
# D . d d d d o M . P d d d D D D D D D D
# d D D d d P o d d d P . d d D D D D D D
# D D d d d d . o d o d D d D D D D D D D
# d D D D d P d D d o d D d D D D D D D D
# D D D D D D D D D . P D D d D d D D D D
# D D D D D D d D D D P d d D D D D D D D
# D D D D D D D D D D D D D D D d d d D D
# D D D D D d d D D d d D D D D d . M d d
# D D D D D D d d D D D D D D P P D d d D
#
# День: 2 Время: Утро (Шаг: 50)
# Существ: 731 (Растений: 710, Травоядных: 16, Хищников: 5)
# D D D D D D d D D D D D D D D d . D D D
# d d D D D D P . M D D D D D D D P D D d
# D d D D D . D D D D D D D D D D D D D d
# D P D D D D d D D D D D D D D D D D d l
# D D . D D D d D D D D D D D D D D D D l
# D D d P D D D D D D D D D D D D D D D D
# P d d D D D D D D D D d D D D D D D D D
# D d D D d D D D D D D d d D D D D D D D
# D D d d d D D d d D D D d D D d d D D D
# D d D d d d . P D d P . M D D . d d D D
# D D . d d d d d d d D D d D D P D D . D
# D P d d P d M . d . d d d D D D D D D M
# D D D D d . d d P d P d d d D D D D D D
# D D d d d P d d d d d D d D D D D D D D
# D D D D d . d D D o d D d D D D D D D D
# D D D D D D D D D P . D D D D d D D D D
# D D D D D D D D D D P D d D D D D D D D
# D D D D D D D D D D D D D D D D d d D D
# D D D D D d D D D d d D D D P d d M d d
# D D D D D D D D D D D D D D P . D D d D
#
# День: 2 Время: Утро (Шаг: 51)
# Существ: 745 (Растений: 724, Травоядных: 16, Хищников: 5)
# D D D D D D D D D D D D D D D D d D D D
# d d D D D D P d M D D D D D D P . D D D
# D D D D D d D D D D D D D D D D D D D D
# D . D D D D D D D D D D D D D D D D D l
# P D d D D D d D D D D D D D D D D D D l
# D D d P D D D D D D D D D D D D D D D D
# P d d D D D D D D D D D D D D D D D D D
# D d D D d D D D D D D d d D D D D D D D
# D D d d D D D d D D D D d D D d d D D D
# D d D d d d d . D d P M . D D d d d D D
# D D d d d D D d P d D D d D D . D D d D
# D P d d . M . P d d d d d D P D D D D .
# D D D D d P d d . d . P d d D D D D D M
# D D d d d P d d d D d D d D D D D D D D
# D D D D d d d D P d d D d D D D D D D D
# D D D D D D D D D P d D D D D D D D D D
# D D D D D D D D D D . D d D D D D D D D
# D D D D D D D D D D D D D D D D d d D D
# D D D D D D D D D d D D D P P d d . d d
# D D D D D D D D D D D D D D . d D D M D
#
# День: 2 Время: Утро (Шаг: 52)
# Существ: 758 (Растений: 737, Травоядных: 16, Хищников: 5)
# D D D D D D D D M D D D D D D D D D D D
# D d D D D D P d . D D D D D D . P D D D
# D D D D D D D D D D D D D D D D D D D D
# D d D D D D D D D D D D D D D D D D D l
# P D D D D D d D D D D D D D D D D D D l
# D D d P D D D D D D D D D D D D D D D D
# P D d D D D D D D D D D D D D D D D D D
# D d D D d D D D D D D d d D D D D D D D
# D D d d D D D D D D D M D D D d d D D D
# D D D d d d d d D D P . d D D D d d D D
# D D d d D D D d P D D D d D D d D D D D
# D P d d d . M . P d d d P D P D D D D d
# D D D D D . d d d d d . d d D D D D D M
# D D D d d P d d d D d D d D D D D D D D
# D D D D d P d D . d D D d D D D D D D D
# D D D D D D D D D P d D D D D D D D D D
# D D D D D D D D P D d D D D D D D D D D
# D D D D D D D D D D D D D D D P d d D D
# D D D D D D D D D D D D D P . d d d d M
# D D D D D D D D D D D D D D d d D D . D
#
# День: 2 Время: Утро (Шаг: 53)
# Существ: 768 (Растений: 747, Травоядных: 16, Хищников: 5)
# D D D D D D D M . D D D D D D P D D D D
# D d D D D D P D d D D D D D D d . D D D
# D D D D D D D D D D D D D D D D D D D D
# P d D D D D D D D D D D D D D D D D D l
# . D D D D D d D D D D D D D D D D D D l
# D D D . D D D D D D D D D D D D D D D D
# P D D D P D D D D D D D D D D D D D D D
# D d D D d D D D D D D d d D D D D D D D
# D D d d D D D D D D D M D D D d d D D D
# D D D d d d D P D D P d d D D D D D D D
# D D D d D D M d . D D D d D D d D D D D
# D . d d d d . d P D d d . D . D D D D D
# P D D D D d d d d d d d P D D P D D D M
# D D D d d P d d d D d D d D D D D D D D
# D D D D d P d D d d D D d D D D D D D D
# D D D D D D D D P . d D D D D D D D D D
# D D D D D D D D P D d D D D D D D D D D
# D D D D D D D D D D D D D D D P d d D D
# D D D D D D D D D D D D D . P d d d D .
# D D D D D D D D D D D D D D D D D D d M
#
# День: 2 Время: День (Шаг: 54)
# Существ: 767 (Растений: 746, Травоядных: 16, Хищников: 5)
# d d d d d d d m . d d d d d d . P d d d
# d d d d d d . P d d d d d d d d . d d d
# d d d d d d d d d d d d d d d d d d d d
# . d d d d d d d d d d d d d d d d d d L
# . P d d d d d d d d d d d d d d d d d L
# P d d P d d d d d d d d d d d d d d d d
# . d d d . d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d P d d d m d d d d d d d d
# d d d d d d d . d d P d d d d d d d d d
# d d d d d d m d . d d d d d d d d d d d
# P . d d d d . d P d d d P d . d d d d d
# . d d d d d d d d d d d . d d . d d d m
# d d d d d P . d d d d d d d d d P d d d
# d d d d d . . d d d d d d d d d d d d d
# d d d d d P d d . P d d d d d d d d d d
# d d d d d d d d P d d d d d d d d d d d
# d d d d d d d d d d d d d d d P d d d d
# d d d d d d d d d d d d d l . P d d d .
# ...
# D D D D d d D d d D d D D D d d D D d l
# D D d D D D D D P D d D D D D D d d D .
# P d d D D D d d D d D d d D d D d d M D
# . d d D d d D d d D d d d D D D d d d D
# D d d d d d D d D d D d d d d d d d d d
# D d d d d d D D D d d D d d d d d d D D
# D d d d d . d d d d d P d d d d d d D D
# d d d d M d d d d d d . d D d d d D d d
# D d d d d d d d d d d d d d d d D d D D
# d d d d d d d d d d d d d D d d d D D D
# d d d d P d d d d d d d d d d d d D D D
# d d d d d d d d d d d d d d M d d d d D
# D D d d d d d d d d d d d D D d d d d D
# D d d P d d d d d d d d d D D M d d d d
# D d d d . d d d d d d d d d d . d d d d
# D D d d d d d d d d d P d d d d d d . M
# D D D D M d d P . d d . d d d d d P d M
# D D D D d . d d d d D d d d d d d . d d
#
# День: 7 Время: Вечер (Шаг: 184)
# Существ: 1583 (Растений: 1569, Травоядных: 7, Хищников: 7)
# D D D D D D D D D d D D D D d d d D D l
# D D D D D D D D d d d D D D d D d d D D
# D D D D D d D d d D d D D D d d D D D d
# D P d D D D D D . D d D D D D D d D M d
# . d d D D D d d P D D d d D d D D d . D
# d d d D D d D d d D d d d D D D d d d D
# D d d d d d D d D d D d d d D d d d d d
# D d d d d d D D D d d D d d D d d d D D
# D d d d d M d d d D P . d d d d d d D D
# d d d d . d d d d d d d d D d d d D D D
# D d d d d d d d d d d d d d d d D D D D
# d d d d d d d d d d d d d D d d d D D D
# d d d d P d d d d d d d d d d d d D D D
# d d d d d d d d d d d d d M . d d d d D
# D D d d d d d d d d d d d D D d d d d D
# D D d . d d d d d d d d d D D . d d d d
# D D D d P d d d d d d d P d d d M d M d
# D D D d d d d d d d d . d d d d d P d .
# D D D D M d d . d d d d d d d d d . d M
# D D D D d d P d d d D d d d d d d d d d
#
# День: 7 Время: Вечер (Шаг: 185)
# Существ: 1595 (Растений: 1581, Травоядных: 7, Хищников: 7)
# D D D D D D D D D D D D D D D d d D D l
# D D D D D D D D d d D D D D d D d d D D
# D P D D D d D D d D d D D D d d D D D D
# D . d D D D D D d D d D D D D D d D . d
# d d d D D D d P . D D d D D d D D D M D
# d d d D D d D d d D d d d D D D d d d D
# D d d d d d D d D d D d d d D d d d d D
# D d d d d M D D D d d D d D D d d d D D
# D d d d d . d d d D P d d d d d d d D D
# d d d d d d d d d d d d D D d d d D D D
# D d d d d d d d d d d d d d d d D D D D
# d d d d d d d d d d d d d D d d d D D D
# d d d d P d d d d d d d d d d d d D D D
# d d d d d d d d d d d d d . d d d d d D
# D D d d d d d d d d d d d M D d d d d D
# D D d d P d d d d d d P d D D d M d d d
# D D D d . d d d d d d d . d d d . d M d
# D D D d d d d d d d d d d d d d d . P d
# D D D D . d d d d d d d d d d d d d M .
# D D D M d d . P d d D D d d d d d d d d
#
# День: 7 Время: Ночь (Шаг: 186)
# Существ: 1598 (Растений: 1584, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d . d d d d p d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d o d d d d d d d d d d d d d
# d d d d P d d d d d d d d d d d d d d d
# d d d d d d d d d d d d o o d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d d . d m d
# d d d d d d d d d d d d d d d d d o p d
# d d d d . d d d d d d d d d d d d d m o
# d d d m d d . p d d d d d d d d d d o d
#
# День: 7 Время: Ночь (Шаг: 187)
# Существ: 1598 (Растений: 1584, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d . d d d d p d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d o d O d d d d d d d d d d d d d
# d d d d P d d d d d d d d d d d d d d d
# d d d d d d d d d d d d O O d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d d . d m d
# d d d d d d d d d d d d d d d d d O p d
# d d d d . d d d d d d d d d d d d d m O
# d d d m d d . p d d d d d d d d d d O d
#
# День: 7 Время: Ночь (Шаг: 188)
# Существ: 1598 (Растений: 1584, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d . d d d d p d d d d d d d d d
# d d d d o d d d d d d d d d d d d d d d
# d d d d o d d o d d d o d d d d d d d d
# d d d d O d O d d d d d o d d d d d d d
# d d d d P d d d d d d o d d d d d d d d
# d d d d d d d d d d d d O O d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d d . d m d
# d d d d d d d d d d d d d d d d d O p d
# d d d d . d d d d d d d d d d d d d m O
# d d d m d d . p d d d d d d d d d d O d
#
# День: 7 Время: Ночь (Шаг: 189)
# Существ: 1598 (Растений: 1584, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d . d d d d p d d d d d d d d d
# d d d d O o d d d d d d d d d d d d d d
# d d o d O d d O d d d O d d d d d d d d
# d d d d O o O d d d d d O o d d d d d d
# d d d d P o o o d o d O d d d d d d d d
# d d d d d d d d d o o o O O d d d d d d
# d d d d d d d d d d d d d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d d . d m d
# d d d d d d d d d d d d d d d d d O p d
# d d d d . d d d d d d d d d d d o d m O
# d d d m d d . p d d d d d d d d d d O d
#
# День: 7 Время: Ночь (Шаг: 190)
# Существ: 1599 (Растений: 1585, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d d . d d d d p d d d d d d d d d
# d d d d O O d d d d d d d d d d d d d d
# d d O d O d o O d d d O d d d d d d d d
# d d d d O o O o d o o o O O d d d d d d
# d d d d P O O O o O o O d o d d d d d d
# d d d d d o o d d O O O O O d d d d d d
# d d d d d d d d d o d d d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d d o d m d
# d d d d d d d d d d d d d d d d d O p d
# d d d d . d d d d d d d d d d o O o m O
# d d d m d d . p d d d d d d d d d d O o
#
# День: 7 Время: Ночь (Шаг: 191)
# Существ: 1599 (Растений: 1585, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d l
# d d d d d d d d d d d d d d d d d d d d
# d p d d d d d d d d d d d d d d d d d d
# d . d d d d d d d d d d d d d d d d . d
# d d d d d d d p . d d d d d d d d d m d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d m d d d d d d d d d d d d d d
# d d d d o . d d d d p d d d d d d d d d
# d d d d O O o d d d d d d d d d d d d d
# d d O o O o o O d o o O o d d d d d d d
# d d d d O O O O o O O O O O d d d d d d
# d d o d P O O O O O o O o O o d d d d d
# d d d d d O O o d O O O O O d d d d d d
# d d d d d d d o o O o o d m d d d d d d
# d d d d p d d d d d d p d d d d m d d d
# d d d d . d d d d d d d . d d o O o m d
# d d d d d d d d d d d d d d d o d O p d
# d d d d . d d d d d d d d d d O O O m O
# d d d m d d . p d d d d d d d o d d O O
#
# День: 8 Время: Утро (Шаг: 192)
# Существ: 1599 (Растений: 1585, Травоядных: 7, Хищников: 7)
# D D d D D D D D d d d D D D D d d d D d
# d d D D d D D d d d d d D D d d d d d d
# d . P D d D d d d d d d D d d d d . D D
# d d d D D D d d d D D D d D d d d D M D
# d d d D D d d P d d d d d D d d d d . D
# d d d d d d d d d D d d d d d D d d d D
# d d d d . d D d d d D d d d d d d d d D
# d d d d d M d D d d d d D d d d d D d d
# D d d d d d d d d d P d d d d d d d d D
# D d d d o o d d d d d d d d d d D d d D
# d d o d o d d o d d d o d d d d d d d D
# d d d d o o o o d o o o o o d d d D D d
# d d d d P o o o o o d o d o d d d d D D
# d d d d d o o d d o o o o . d d d d d D
# d D d d d d d d d o d d d . M d d d d D
# D D d d . d d d d d d . d d D d . . d d
# D d d d d P d d d d d P d d d d . M M P
# D D D . d d d d d d d d d d d d d o . d
# D D D D M d P d d d d d d d d o o o . M
# D D D . d d d . d d d d d d d d d d . o
#
# День: 8 Время: Утро (Шаг: 193)
# Существ: 1614 (Растений: 1600, Травоядных: 7, Хищников: 7)
# D D D D D D D D d d d D D D D d d d D D
# d d D D d D D d d d d d D D d d d d D D
# d d . P d D d d d d d d D D d d d M D D
# D d d D D D d d d D D D d D d d d D . D
# d d d D D D d P d D d d d D d d D d d D
# d d d d D d d d d D d d d d D D d d d D
# D d d d d d D d d d D d d d d d d d d D
# d d d d d M D D d d d d D d d D d D d d
# D d d d d d D d d d . d d d d d d d D D
# D d d d d d d d d d P d d d d d D D d D
# d d d d d d d d d d d d d d D d d D d D
# d d d d d d d d d d d d d d d d d D D D
# d d d d P d d d d d d d d d D d d d D D
# D d d d d d d d d d d d o d d d d d d D
# D D d d d d d d d d d d d d . d d d d D
# D D d d d d d d d d d d P M D d d M d M
# D D d d P . d d d d d . d d d d d . . P
# D D D d d d d d d d d d d d d d d d M d
# D D D M . d P d d d d d d d d d d d d .
# D D D . d d d d d d d d D d d d d d d d
#
# День: 8 Время: Утро (Шаг: 194)
# Существ: 1624 (Растений: 1610, Травоядных: 7, Хищников: 7)
# D D D D D D D D d d d D D D D D d d D D
# D d P D d D D d d d d D D D d d d d D D
# d d d . D D d d d d d d D D D d d . D D
# D d d D D D D d d D D D d D D d d D M D
# d d d D D D d P d D d d d D d d D d d D
# d d d d D d d d d D d d d d D D d d d D
# D d d d d d D d D d D d d d d d d d d D
# d d D d d . D D d d d d D d d D d D D d
# D d d d d M D d d d P d d d d d d d D D
# D d d d d d d d d d . d d D d d D D d D
# d d d d d d d d d d d d d d D d d D d D
# d d d d d d d d d d d d d d d d d D D D
# d d d d P d d d d d d d d d D d d d D D
# D d d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d M d d d d d d D
# D D d d P d d d d d d d P . D d M . d M
# D D D d . d d d d d d d d d d d d d d .
# D D D d d d d d d d d d d d d d d d . P
# D D M . d d P d d d d d d d d d d d d M
# D D D . D d d d d D d d D d d d d d d d
#
# День: 8 Время: Утро (Шаг: 195)
# Существ: 1635 (Растений: 1621, Травоядных: 7, Хищников: 7)
# D D D D D D D D D d D D D D D D d d D D
# D d . D D D D d d d d D D D D d d d D D
# d D d P D D D D d d d d D D D d d d D D
# D d d D D D D D d D D D d D D d d D . D
# d D d D D D D P d D d D d D D d D d M D
# d d d d D d d d d D d d d d D D d d d D
# D d d d d d D d D d D d d d d d d d d D
# d d D d d d D D d d d d D d d D d D D d
# D d d d d . D d d d P d d d d d d d D D
# D d d d d d M d d d d d d D D d D D D D
# d d d d d d d d d d d d d d D d d D D D
# d d d d d d d d d d d d d d d d D D D D
# d d d d P d d d d d d d d d D d d D D D
# D d d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d . d d d d d d D
# D D d d . d d d d d d d M d D d . d d M
# D D D P d d d d d d d d P d d d d M d d
# D D D d d d d d d d d d d d d d d d d P
# D D . M d P . d d d d d d d d d d d d .
# D D D d D d d d d D d d D d d d d d M d
#
# День: 8 Время: Утро (Шаг: 196)
# Существ: 1644 (Растений: 1630, Травоядных: 7, Хищников: 7)
# D D D D D D D D D d D D D D D D d d D D
# D d d D D D D d d d d D D D D d d d D D
# d D d . D D D D d d d d D D D d d d D D
# D d d P D D D D d D D D d D D d D D d D
# d D d D D D D . d D d D d D D D D d . D
# d d d d D d d d P D d d d d D D d M d D
# D d d d d d D d D d D d d d d d d d d D
# d d D d d d D D d D d d D d d D d D D D
# D d d d D d D d d d P d d d d d d d D D
# D d d d d M . d d d d d d D D d D D D D
# d d d d d d d d d d d d d d D d d D D D
# d d d d d d d d d d d d d d d d D D D D
# d d d d P d d d d d d d d d D d d D D D
# D d d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d M d d d d d d D
# D D d d d d d d d d d d . d D d d d d M
# D D D P d d d d d d d d P d d d d M d d
# D D M d d d d d d d d d d d d d d d d .
# D D d . d . d d d d d d d d d d d d M P
# D D D D P d d d d D d d D d d d d d . d
#
# День: 8 Время: Утро (Шаг: 197)
# Существ: 1653 (Растений: 1639, Травоядных: 7, Хищников: 7)
# D D D D D D D D D d D D D D D D d D D D
# D D d D D D D D d D d D D D D d d d D D
# d D D d D D D D d D d D D D D d d D D D
# D d P . D D D D d D D D d D D d D D d D
# D D d D D D D d d D d D d D D D D d d D
# d d d d D d d d P D d d d D D D d M d D
# D d d d D d D d D d D d d d d d d d d D
# d d D d d d D D d D d d D d d D D D D D
# D d d d D d D d d d P d d d d d d d D D
# D d d d d . M d d d d d d D D d D D D D
# d d d d d d d d d d d d d d D d D D D D
# d d d d d d d d d d d d d d d d D D D D
# d d d d P d d d d d d d d d D d d D D D
# D d d d d d d d d d d d M d d d d d d D
# D D d d d d d d d d d d . d d d d d d D
# D D P d d d d d d d d d P d D d d d d M
# D D D . d d d d d d d d . d d d M . d d
# D D . d d d d d d d d d d d d d d d d d
# D D M d d d d d d d d d d d d d d d . M
# D D D P . d d d d D d d D d d d d d d P
#
# День: 8 Время: День (Шаг: 198)
# Существ: 1652 (Растений: 1638, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d l d d d
# d d d d d d d d d d d d d d d d l d d d
# d P . . d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d P d d d d d d d d m d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d . m d d P d d d d d d d d d d
# d d d d l l d d d d d d d d d d d d d d
# d l l d d d d d d d d d d d d d d d d d
# d l l l P l d d d d d d d d d d d d d d
# d d . l l l l d d d d d m d d d d d d d
# d d P l l l d d d d d d . d d d d d d d
# d d . l l l l l d d d d P d d d d d d m
# d d d . l d l d l d d d . d d d m . d d
# d d . d d l d l d d d d d d d d d d d d
# d d m d l l l l d d d d d d d d d d . m
# d d P . . d d d d d d d d d d d d d d P
#
# День: 8 Время: День (Шаг: 199)
# Существ: 1656 (Растений: 1642, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d l d l d d
# d d d d d d d d d d d d d d d d L d d d
# d d d d d d d d d d d d d d d d L l l d
# d . . . d d d d d d d d d d d d d d d d
# d d P d d d d d d d d d d d d d d d d d
# d d d d d d d d . d d d d d d d d m d d
# d d d l d d d d d P d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d l d d d d d d . d d d l d d l d d
# d d d d l l m d d P d d d d d d d d d d
# d d l d l L l l d d d d d d d d d d d d
# d L l l l l l d d d d d d d d d d d d d
# l l L l P l d d d d d d d d d d d d d d
# l d l l l L L d d d d d m d d d d d d d
# d P . l l l l d l d d d . d d d d d d d
# d d l L l l l L d d d d . P d d d d d m
# d d l l l l l d L l d d . d d d m . d d
# d d . d l l l l d d d d d d d d d d d d
# d d m d L L l L d d d d d l d d d d P m
# d d P . . d l d d d d d d d d d d d d .
#
# День: 8 Время: День (Шаг: 200)
# Существ: 1656 (Растений: 1642, Травоядных: 7, Хищников: 7)
# d d d d d d d d d d d d d d d L l L d d
# d d d d d d d d d d d d d d l l L l d d
# d d d d d d d d d d d d d d d l L l L d
# d . . . d d d d d d d d d d d d l l l l
# d d . d d d d d d d d d d d d d d d d d
# d d P d d d d d . d d d d d d d d m d d
# d d d . d d d d d P d d d d d d l d l d
# d d d d d d d d d d d d d d l d l d d l
# d d d L l l d d d d . d d d L d d L l d
# d d l d L L m d d P d d d d d l d d d d
# d l L l l L L L d d d d d d d d d d d d
# l L L l L L L l d d d d d d d d d d d d
# l l L l P l l d d d d d d d d d d d d d
# L l l l l L L d d d d d m d d d d d d d
# P . l l l l l l L d d d . d d d d d d d
# d l L L l L L L l d d d P . d d d d d m
# d d l l L L l l L L d d . d d d m . d d
# d d . l l l l l l l d d d d d d d d d d
# d d m . L L l L d d d d d L l d d d P m
# d d . P l d L l d d d d d d d d d d d .
#
# Симуляция завершена.
# Итоговые показатели: День 8, Всего существ: 1656
# Растений: 1642
# Травоядных: 7
# Хищников: 7
